# %% [markdown]
# # CSMODEL Machine Project:
#
# This Jupyter Notebook includes the following contents:
#
#     0.  2023 Global Youtube Statistics Dataset
#     1.  Description of the Dataset
#     2.  Data Cleaning Process of the Dataset
#     3.  Exploratory Data Analysis
#     4.  Proposed Research Question
#     5.  Data Preprocessing
#     6.  Data Modelling
#     7.  Statistical Inference
#     8.  Insights and Conclusion
#
# ### GARYNATION  (S13)
#     1.  Bien Aaron Miranda
#     2.  Luis Miguel Rana
#     3.  Karl Andre Aquino
#     4.  Dominic Luis Baccay

# %% [markdown]
# # Phase 1

# %% [markdown]
# ### Python Libraries
#
# Import numpy and pandas.
#
# pandas is a software library for Python which provides data structures and data analysis tools.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import chi2_contingency
from scipy import stats
from pandas import factorize

# %% [markdown]
# ## The Dataset
# This dataset, which includes well-known YouTube personalities, offers a compelling opportunity to analyze and glean invaluable insights from the influential figures within the platform. It contains comprehensive details on subscriber counts, video views, posting frequency, country of origin, income, and other relevant information about top creators. This treasure trove of data is indispensable for up-and-coming content creators, data aficionados, and anyone intrigued by the dynamic landscape of online content creation.
#
# As stated by the dataset owner, dataset was painstakingly and diligently compiled from an array of highly regarded and credible sources, meticulously curating its contents to guarantee the utmost accuracy and unwavering reliability of the information it encapsulates, thereby instilling confidence in the veracity of the presented data.

# %%
#encoding came from the discussion so that it is readable
youtube_df = pd.read_csv("Global YouTube Statistics.csv", encoding='iso-8859-1')

# %% [markdown]
# If you view the `.csv` file in Excel, you can see that our dataset contains about 995 **observations** (rows) across 28 **variables** (columns). The following are the descriptions of each variable in the dataset.
#
# - **`rank`**: Position of the YouTube channel based on the number of subscribers
# - **`Youtuber`**: Name of the YouTube channel
# - **`subscribers`**: Number of subscribers to the channel
# - **`video views`**: Overall count views to the channel
# - **`category`**: Category or niche of the channel
# - **`Title`**: Title
# - **`uploads`**: Total number of videos uploaded on the channel
# - **`Country`**: Country where the YouTube channel originates
# - **`Abbreviation`**: Abbreviation of the country
# - **`channel_type`**: Type of the YouTube channel (e.g., individual, brand)
# - **`video_views_rank`**: Ranking of the channel based on total video views
# - **`country_rank`**: Ranking of the channel based on the number of subscribers within its country
# - **`channel_type_rank`**: Ranking of the channel based on its type (individual or brand)
# - **`video_views_for_the_last_30_days`**: Total video views in the last 30 days
# - **`lowest_monthly_earnings`**: Lowest estimated monthly earnings from the channel \$
# - **`highest_monthly_earnings`**: Highest estimated monthly earnings from the channel \$
# - **`lowest_yearly_earnings`**: Lowest estimated yearly earnings from the channel \$
# - **`highest_yearly_earnings`**: Highest estimated yearly earnings from the channel $
# - **`subscribers_for_last_30_days`**: Number of new subscribers gained in the last 30 days
# - **`created_year`**: Year when the YouTube channel was created
# - **`created_month`**: Month when the YouTube channel was created
# - **`created_date`**: Exact date of the YouTube channel's creation
# - **`Gross tertiary education enrollment (\%)`**: Percentage of the population enrolled in tertiary education in the country %
# - **`Population`**: Total population of the country
# - **`Unemployment rate`**: Unemployment rate in the country %
# - **`Urban_population`**: Percentage of the population living in urban areas %
# - **`Latitude`**: Latitude coordinate of the country's location
# - **`Longitude`**: Longitude coordinate of the country's location

# %% [markdown]
# ## Reading the Dataset
#
# Our first step is to load the dataset using pandas. This will load the dataset into a pandas DataFrame. To load the dataset, we use the read_csv function. Note that you may need to change the path depending on the location of the file in your machine.
#
# Will also tackle about what can be seen in the Dataset as a DataFrame

# %%
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
#  10  video_views_rank                         994 non-null    float64
#  11  country_rank                             879 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  995 non-null    float64
#  15  highest_monthly_earnings                 995 non-null    float64
#  16  lowest_yearly_earnings                   995 non-null    float64
#  17  highest_yearly_earnings                  995 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    float64
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  872 non-null    float64
#  23  Population                               872 non-null    float64
#  24  Unemployment rate                        872 non-null    float64
#  25  Urban_population                         872 non-null    float64
#  26  Latitude                                 872 non-null    float64
#  27  Longitude                                872 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 217.8+ KB

# %% [markdown]
# ### Examining the observations within the Dataset
#
#
# To gain a better understanding of the observations within the dataset, it's essential to examine their appearance or visual representation. This can provide valuable insights and help you make informed decisions based on the data.

# %%
youtube_df.head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
# 5               NaN                       Music        0            NaN
# 6    People & Blogs         ýýý Kids Diana Show     1111  United States
# 7            Gaming                   PewDiePie     4716          Japan
# 8    People & Blogs            Like Nastya Vlog      493         Russia
# 9     Entertainment               Vlad and Niki      574  United States
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
# 5          NaN          Music  ...                           NaN
# 6           US  Entertainment  ...                           NaN
# 7           JP  Entertainment  ...                           NaN
# 8           RU         People  ...                      100000.0
# 9           US  Entertainment  ...                      600000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
# 5        2013.0            Sep          24.0
# 6        2015.0            May          12.0
# 7        2010.0            Apr          29.0
# 8        2016.0            Jan          14.0
# 9        2018.0            Apr          23.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
# 5                                      NaN           NaN                NaN
# 6                                     88.2  3.282395e+08              14.70
# 7                                     63.2  1.262266e+08               2.29
# 8                                     81.9  1.443735e+08               4.59
# 9                                     88.2  3.282395e+08              14.70
#
#    Urban_population   Latitude   Longitude
# 0       471031528.0  20.593684   78.962880
# 1       270663028.0  37.090240  -95.712891
# 2       270663028.0  37.090240  -95.712891
# 3       270663028.0  37.090240  -95.712891
# 4       471031528.0  20.593684   78.962880
# 5               NaN        NaN         NaN
# 6       270663028.0  37.090240  -95.712891
# 7       115782416.0  36.204824  138.252924
# 8       107683889.0  61.524010  105.318756
# 9       270663028.0  37.090240  -95.712891
#
# [10 rows x 28 columns]

# %% [markdown]
# # Cleaning the Dataset
#
#     This section of the Jupyter Notebook contains the overall process and variables affected during the data cleaning of our dataset.

# %% [markdown]
# ### Before Cleaning:
#     Number of Observations: 995
#     Number of Columns: 28
#     Data types: float64(18), int64(3), object(7)
#
# ### Initial Observations:
# -   There are special characters in the 'Youtuber' column.
# -   There are missing/null values in the dataset.
# -   Some variables are similar, therefore, unnecessary.
# -   Some data types are inappropriate for their respective variables.

# %% [markdown]
# #### Variables to be Observed:
# We will be dropping all columns/variables except the following.
# - **`Youtuber`**: Name of the YouTube channel
# - **`subscribers`**: Number of subscribers to the channel
# - **`video views`**: Overall count views to the channel
# - **`category`**: Category or niche of the channel
# - **`uploads`**: Total number of videos uploaded on the channel
# - **`Country`**: Country where the YouTube channel originates
# - **`channel_type`**: Type of the YouTube channel (e.g., individual, brand)
# - **`lowest_monthly_earnings`**: Lowest estimated monthly earnings from the channel \$
# - **`highest_monthly_earnings`**: Highest estimated monthly earnings from the channel \$
# - **`lowest_yearly_earnings`**: Lowest estimated yearly earnings from the channel \$
# - **`highest_yearly_earnings`**: Highest estimated yearly earnings from the channel $
# - **`created_year`**: Year when the YouTube channel was created
# - **`Population`**: Total population of the country

# %%
# Declare the variables that will be used
columns_to_keep = ['Youtuber', 'subscribers', 'video views', 'uploads', 'category', 'channel_type', 'Country', 'lowest_monthly_earnings', 'highest_monthly_earnings', 'lowest_yearly_earnings', 'highest_yearly_earnings', 'created_year', 'Population']
columns_to_drop = list(set(youtube_df.columns) - set(columns_to_keep))

# Drop unused columns (variables)
youtube_df.drop(columns_to_drop, axis=1, inplace=True)

youtube_df
# Out:
#                        Youtuber  subscribers   video views          category  \
# 0                      T-Series    245000000  2.280000e+11             Music
# 1                YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2                       MrBeast    166000000  2.836884e+10     Entertainment
# 3    Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 4                     SET India    159000000  1.480000e+11             Shows
# ..                          ...          ...           ...               ...
# 990               Natan por Aï¿     12300000  9.029610e+09            Sports
# 991    Free Fire India Official     12300000  1.674410e+09    People & Blogs
# 992                       Panda     12300000  2.214684e+09               NaN
# 993                 RobTopGames     12300000  3.741235e+08            Gaming
# 994                Make Joke Of     12300000  2.129774e+09            Comedy
#
#      uploads         Country   channel_type  lowest_monthly_earnings  \
# 0      20082           India          Music                 564600.0
# 1          1   United States          Games                      0.0
# 2        741   United States  Entertainment                 337000.0
# 3        966   United States      Education                 493800.0
# 4     116536           India  Entertainment                 455900.0
# ..       ...             ...            ...                      ...
# 990     1200          Brazil  Entertainment                 138100.0
# 991     1500           India          Games                  16200.0
# 992     2452  United Kingdom          Games                     17.0
# 993       39          Sweden          Games                    968.0
# 994       62           India         Comedy                   6000.0
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 0                  9000000.00              6800000.00
# 1                        0.05                    0.04
# 2                  5400000.00              4000000.00
# 3                  7900000.00              5900000.00
# 4                  7300000.00              5500000.00
# ..                        ...                     ...
# 990                2200000.00              1700000.00
# 991                 258900.00               194200.00
# 992                    268.00                  201.00
# 993                  15500.00                11600.00
# 994                  96000.00                72000.00
#
#      highest_yearly_earnings  created_year    Population
# 0               1.084000e+08        2006.0  1.366418e+09
# 1               5.800000e-01        2006.0  3.282395e+08
# 2               6.470000e+07        2012.0  3.282395e+08
# 3               9.480000e+07        2006.0  3.282395e+08
# 4               8.750000e+07        2006.0  1.366418e+09
# ..                       ...           ...           ...
# 990             2.650000e+07        2017.0  2.125594e+08
# 991             3.100000e+06        2018.0  1.366418e+09
# 992             3.200000e+03        2006.0  6.683440e+07
# 993             1.858000e+05        2012.0  1.028545e+07
# 994             1.200000e+06        2017.0  1.366418e+09
#
# [995 rows x 13 columns]

# %% [markdown]
# ### The "Youtuber" variable
#
# - **`Youtuber`**: Name of the YouTube channel<br>
#
# We will explore the **`Youtuber`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any observations that have null **`Youtuber`** values, if any, we will be excluding these observations from the list.

# %%
# Check for null values
column_name = "Youtuber"
nullyoutuber_count = youtube_df["Youtuber"].isnull().sum()
print(f"Number of unique values in '{column_name}': {nullyoutuber_count}")
# Out:
# Number of unique values in 'Youtuber': 0

# %% [markdown]
# We want to check if there are any duplicate **`Youtuber`** values, if any, the row will be removed.

# %%
# Check for duplicates
unique_count = youtube_df[column_name].nunique()
observation_count = youtube_df[column_name].count()

print(f"Number of observations in '{column_name}': {observation_count}")
print(f"Number of unique values in '{column_name}': {unique_count}")
# Out:
# Number of observations in 'Youtuber': 995
# Number of unique values in 'Youtuber': 995

# %% [markdown]
# Since there are special characters present within the dataset, we will replace them with underscores "_" instead for readability.

# %%
# Define an array of special characters to replace
chars_to_replace = ['ï', '¿', '½', 'ý']

# Replace the characters with underscores
for char in chars_to_replace:
    youtube_df['Youtuber'] = youtube_df['Youtuber'].str.replace(char, '_', regex=False)

youtube_df
# Out:
#                        Youtuber  subscribers   video views          category  \
# 0                      T-Series    245000000  2.280000e+11             Music
# 1                YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2                       MrBeast    166000000  2.836884e+10     Entertainment
# 3    Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 4                     SET India    159000000  1.480000e+11             Shows
# ..                          ...          ...           ...               ...
# 990               Natan por A__     12300000  9.029610e+09            Sports
# 991    Free Fire India Official     12300000  1.674410e+09    People & Blogs
# 992                       Panda     12300000  2.214684e+09               NaN
# 993                 RobTopGames     12300000  3.741235e+08            Gaming
# 994                Make Joke Of     12300000  2.129774e+09            Comedy
#
#      uploads         Country   channel_type  lowest_monthly_earnings  \
# 0      20082           India          Music                 564600.0
# 1          1   United States          Games                      0.0
# 2        741   United States  Entertainment                 337000.0
# 3        966   United States      Education                 493800.0
# 4     116536           India  Entertainment                 455900.0
# ..       ...             ...            ...                      ...
# 990     1200          Brazil  Entertainment                 138100.0
# 991     1500           India          Games                  16200.0
# 992     2452  United Kingdom          Games                     17.0
# 993       39          Sweden          Games                    968.0
# 994       62           India         Comedy                   6000.0
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 0                  9000000.00              6800000.00
# 1                        0.05                    0.04
# 2                  5400000.00              4000000.00
# 3                  7900000.00              5900000.00
# 4                  7300000.00              5500000.00
# ..                        ...                     ...
# 990                2200000.00              1700000.00
# 991                 258900.00               194200.00
# 992                    268.00                  201.00
# 993                  15500.00                11600.00
# 994                  96000.00                72000.00
#
#      highest_yearly_earnings  created_year    Population
# 0               1.084000e+08        2006.0  1.366418e+09
# 1               5.800000e-01        2006.0  3.282395e+08
# 2               6.470000e+07        2012.0  3.282395e+08
# 3               9.480000e+07        2006.0  3.282395e+08
# 4               8.750000e+07        2006.0  1.366418e+09
# ..                       ...           ...           ...
# 990             2.650000e+07        2017.0  2.125594e+08
# 991             3.100000e+06        2018.0  1.366418e+09
# 992             3.200000e+03        2006.0  6.683440e+07
# 993             1.858000e+05        2012.0  1.028545e+07
# 994             1.200000e+06        2017.0  1.366418e+09
#
# [995 rows x 13 columns]

# %% [markdown]
# ### The "Subscribers" variable
#
# - **`subscribers`**: Number of subscribers to the channel<br>
#
# We will explore the **`subscribers`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any observations with null **`subscribers`** values.

# %%
# Display the counts
null_subscriber_count = youtube_df['subscribers'].eq(0).sum()
print(f'Number of null values in "subscribers": {null_subscriber_count}')
# Out:
# Number of null values in "subscribers": 0

# %% [markdown]
# Since there are none, we now want to convert the data type from **`int64`** to **`float64`** for scaling. <br>
# We will scale the values to millions, so we will need to convert the data type to one that can recognize decimals. <br>
# We are scaling the values for easier interpretation and visualization.

# %%
# Convert to float64 data type
youtube_df['subscribers'] = youtube_df['subscribers'].astype('float64')
# Convert the "subscribers" column to values in millions
youtube_df['subscribers'] = youtube_df['subscribers'] / 1000000
# Rename the "subscribers" column to indicate values are in millions
youtube_df.rename(columns={'subscribers': 'subscribers (millions)'}, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)   video views  \
# 0                      T-Series                   245.0  2.280000e+11
# 1                YouTube Movies                   170.0  0.000000e+00
# 2                       MrBeast                   166.0  2.836884e+10
# 3    Cocomelon - Nursery Rhymes                   162.0  1.640000e+11
# 4                     SET India                   159.0  1.480000e+11
# ..                          ...                     ...           ...
# 990               Natan por A__                    12.3  9.029610e+09
# 991    Free Fire India Official                    12.3  1.674410e+09
# 992                       Panda                    12.3  2.214684e+09
# 993                 RobTopGames                    12.3  3.741235e+08
# 994                Make Joke Of                    12.3  2.129774e+09
#
#              category  uploads         Country   channel_type  \
# 0               Music    20082           India          Music
# 1    Film & Animation        1   United States          Games
# 2       Entertainment      741   United States  Entertainment
# 3           Education      966   United States      Education
# 4               Shows   116536           India  Entertainment
# ..                ...      ...             ...            ...
# 990            Sports     1200          Brazil  Entertainment
# 991    People & Blogs     1500           India          Games
# 992               NaN     2452  United Kingdom          Games
# 993            Gaming       39          Sweden          Games
# 994            Comedy       62           India         Comedy
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                9000000.00
# 1                        0.0                      0.05
# 2                   337000.0                5400000.00
# 3                   493800.0                7900000.00
# 4                   455900.0                7300000.00
# ..                       ...                       ...
# 990                 138100.0                2200000.00
# 991                  16200.0                 258900.00
# 992                     17.0                    268.00
# 993                    968.0                  15500.00
# 994                   6000.0                  96000.00
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                6800000.00             1.084000e+08        2006.0
# 1                      0.04             5.800000e-01        2006.0
# 2                4000000.00             6.470000e+07        2012.0
# 3                5900000.00             9.480000e+07        2006.0
# 4                5500000.00             8.750000e+07        2006.0
# ..                      ...                      ...           ...
# 990              1700000.00             2.650000e+07        2017.0
# 991               194200.00             3.100000e+06        2018.0
# 992                  201.00             3.200000e+03        2006.0
# 993                11600.00             1.858000e+05        2012.0
# 994                72000.00             1.200000e+06        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    3.282395e+08
# 4    1.366418e+09
# ..            ...
# 990  2.125594e+08
# 991  1.366418e+09
# 992  6.683440e+07
# 993  1.028545e+07
# 994  1.366418e+09
#
# [995 rows x 13 columns]

# %% [markdown]
# We also renamed the column from **`"subscribers"`** to **`"subscribers (millions)"`**.

# %% [markdown]
# ### The "Video Views" and "Uploads" variables
# - **`video views`**: Overall count views to the channel
# - **`uploads`**: Total number of videos uploaded on the channel<br>
#
# We will explore the **`video views`** and **`uploads`** columns and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any observations that have null or zero values in these columns.

# %%
# Check for null values in "video views"
nullviews_df = youtube_df[youtube_df['video views'] == 0]
nullviews_df
# Out:
#                Youtuber  subscribers (millions)  video views  \
# 1        YouTube Movies                   170.0          0.0
# 5                 Music                   119.0          0.0
# 12               Gaming                    93.6          0.0
# 18               Sports                    75.0          0.0
# 102                News                    36.3          0.0
# 173  Popular on YouTube                    29.3          0.0
# 360   Minecraft - Topic                    20.9          0.0
# 592                Live                    16.1          0.0
#
#              category  uploads        Country   channel_type  \
# 1    Film & Animation        1  United States          Games
# 5                 NaN        0            NaN          Music
# 12                NaN        0            NaN          Games
# 18                NaN        3  United States  Entertainment
# 102               NaN        0            NaN            NaN
# 173               NaN        3            NaN      Education
# 360               NaN        0            NaN          Games
# 592               NaN        0            NaN            NaN
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 1                        0.0                      0.05
# 5                        0.0                      0.00
# 12                       0.0                      0.00
# 18                       0.0                      0.06
# 102                      0.0                      0.00
# 173                      0.0                      0.00
# 360                      0.0                      0.00
# 592                      0.0                      0.00
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 1                      0.04                     0.58        2006.0
# 5                      0.00                     0.00        2013.0
# 12                     0.00                     0.00        2013.0
# 18                     0.05                     0.77        2006.0
# 102                    0.00                     0.00        2013.0
# 173                    0.00                     0.05        2017.0
# 360                    0.00                     0.00        2013.0
# 592                    0.00                     0.00        2015.0
#
#       Population
# 1    328239523.0
# 5            NaN
# 12           NaN
# 18   328239523.0
# 102          NaN
# 173          NaN
# 360          NaN
# 592          NaN

# %%
# Check for null values in "uploads"
nulluploads_df = youtube_df[youtube_df['uploads'] == 0]
nulluploads_df.head(10)
# Out:
#                  Youtuber  subscribers (millions)   video views  \
# 5                   Music                   119.0  0.000000e+00
# 12                 Gaming                    93.6  0.000000e+00
# 57            BRIGHT SIDE                    44.5  1.070853e+10
# 73       Luisito Comunica                    40.6  8.670474e+09
# 102                  News                    36.3  0.000000e+00
# 113  T-Series Apna Punjab                    34.6  2.130632e+10
# 149            Luis Fonsi                    31.4  1.517676e+10
# 166         Frost Diamond                    30.1  7.277494e+09
# 180    Aditya Music India                    28.5  2.585799e+10
# 190    Sandeep Maheshwari                    27.8  2.303069e+09
#
#            category  uploads    Country channel_type  lowest_monthly_earnings  \
# 5               NaN        0        NaN        Music                      0.0
# 12              NaN        0        NaN        Games                      0.0
# 57    Howto & Style        0        NaN          NaN                      0.0
# 73           Comedy        0     Mexico       Comedy                      0.0
# 102             NaN        0        NaN          NaN                      0.0
# 113           Music        0        NaN         News                      0.0
# 149   Entertainment        0        NaN          NaN                      0.0
# 166          Gaming        0        NaN          NaN                      0.0
# 180           Music        0        NaN        Music                      0.0
# 190  People & Blogs        0  Singapore          NaN                      0.0
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 5                         0.0                     0.0
# 12                        0.0                     0.0
# 57                        0.0                     0.0
# 73                        0.0                     0.0
# 102                       0.0                     0.0
# 113                       0.0                     0.0
# 149                       0.0                     0.0
# 166                       0.0                     0.0
# 180                       0.0                     0.0
# 190                       0.0                     0.0
#
#      highest_yearly_earnings  created_year   Population
# 5                        0.0        2013.0          NaN
# 12                       0.0        2013.0          NaN
# 57                       0.0        2005.0          NaN
# 73                       0.0        2010.0  126014024.0
# 102                      0.0        2013.0          NaN
# 113                      0.0        2020.0          NaN
# 149                      0.0        2006.0          NaN
# 166                      0.0        2006.0          NaN
# 180                      0.0        2010.0          NaN
# 190                      0.0        2008.0    5703569.0

# %%
# Display the counts
null_views_count = youtube_df['video views'].eq(0).sum()
null_uploads_count = youtube_df['uploads'].eq(0).sum()
print(f'Number of null values in "video views": {null_views_count}')
print(f'Number of null values in "uploads": {null_uploads_count}')
# Out:
# Number of null values in "video views": 8
# Number of null values in "uploads": 43

# %% [markdown]
# We want to scale the **`video views`** into millions for easier interpretation and visualization.

# %%
# Convert the "video views" column to values in millions
youtube_df['video views'] = youtube_df['video views'] / 1000000
# Rename the "subscribers" column to indicate values are in millions
youtube_df.rename(columns={'video views': 'video views (millions)'}, inplace=True)

# %%
youtube_df['uploads'] = youtube_df['uploads'].astype('float64')

# %% [markdown]
# We want to see if there are any correlations between the **`video views (millions)`** and **`uploads`** with their respective indexes.

# %%
# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot 'video views' (in millions) in the first subplot
axs[0].scatter(youtube_df.index, youtube_df['video views (millions)'])
axs[0].set_title('Correlation between Video Views (Millions) and Index')
axs[0].set_xlabel('Index')
axs[0].set_ylabel('Video Views (Millions)')

# Plot 'upload' in the second subplot
axs[1].scatter(youtube_df.index, youtube_df['uploads'], color='red')
axs[1].set_title('Correlation between Upload and Index')
axs[1].set_xlabel('Index')
axs[1].set_ylabel('Upload')

# Adjust the layout for better spacing
plt.tight_layout()

# Show the combined figure
plt.show()

# %% [markdown]
# Given the absence of significant correlations between **`video views`**, **`uploads`**, and their respective indexes, the decision has been made to remove the observations in question rather than replacing them with measures of central tendencies.

# %%
# Drop the rows where video views == 0
youtube_df = youtube_df[youtube_df["video views (millions)"] != 0]

# Drop the rows where uploads == 0
youtube_df = youtube_df[youtube_df["uploads"] != 0]
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 2                       MrBeast                   166.0
# 3    Cocomelon - Nursery Rhymes                   162.0
# 4                     SET India                   159.0
# 6           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 990               Natan por A__                    12.3
# 991    Free Fire India Official                    12.3
# 992                       Panda                    12.3
# 993                 RobTopGames                    12.3
# 994                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 2              28368.841870   Entertainment     741.0   United States
# 3             164000.000000       Education     966.0   United States
# 4             148000.000000           Shows  116536.0           India
# 6              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 990             9029.609749          Sports    1200.0          Brazil
# 991             1674.409945  People & Blogs    1500.0           India
# 992             2214.684303             NaN    2452.0  United Kingdom
# 993              374.123483          Gaming      39.0          Sweden
# 994             2129.773714          Comedy      62.0           India
#
#       channel_type  lowest_monthly_earnings  highest_monthly_earnings  \
# 0            Music                 564600.0                 9000000.0
# 2    Entertainment                 337000.0                 5400000.0
# 3        Education                 493800.0                 7900000.0
# 4    Entertainment                 455900.0                 7300000.0
# 6    Entertainment                 182900.0                 2900000.0
# ..             ...                      ...                       ...
# 990  Entertainment                 138100.0                 2200000.0
# 991          Games                  16200.0                  258900.0
# 992          Games                     17.0                     268.0
# 993          Games                    968.0                   15500.0
# 994         Comedy                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 2                 4000000.0               64700000.0        2012.0
# 3                 5900000.0               94800000.0        2006.0
# 4                 5500000.0               87500000.0        2006.0
# 6                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 990               1700000.0               26500000.0        2017.0
# 991                194200.0                3100000.0        2018.0
# 992                   201.0                   3200.0        2006.0
# 993                 11600.0                 185800.0        2012.0
# 994                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 2    3.282395e+08
# 3    3.282395e+08
# 4    1.366418e+09
# 6    3.282395e+08
# ..            ...
# 990  2.125594e+08
# 991  1.366418e+09
# 992  6.683440e+07
# 993  1.028545e+07
# 994  1.366418e+09
#
# [949 rows x 13 columns]

# %% [markdown]
# After removing the observations, we will be resetting the indexes ensure there are no gaps and the data remains continuous.

# %%
# Reset the index after dropping rows
youtube_df.reset_index(drop=True, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 944               Natan por A__                    12.3
# 945    Free Fire India Official                    12.3
# 946                       Panda                    12.3
# 947                 RobTopGames                    12.3
# 948                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 944             9029.609749          Sports    1200.0          Brazil
# 945             1674.409945  People & Blogs    1500.0           India
# 946             2214.684303             NaN    2452.0  United Kingdom
# 947              374.123483          Gaming      39.0          Sweden
# 948             2129.773714          Comedy      62.0           India
#
#       channel_type  lowest_monthly_earnings  highest_monthly_earnings  \
# 0            Music                 564600.0                 9000000.0
# 1    Entertainment                 337000.0                 5400000.0
# 2        Education                 493800.0                 7900000.0
# 3    Entertainment                 455900.0                 7300000.0
# 4    Entertainment                 182900.0                 2900000.0
# ..             ...                      ...                       ...
# 944  Entertainment                 138100.0                 2200000.0
# 945          Games                  16200.0                  258900.0
# 946          Games                     17.0                     268.0
# 947          Games                    968.0                   15500.0
# 948         Comedy                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 944               1700000.0               26500000.0        2017.0
# 945                194200.0                3100000.0        2018.0
# 946                   201.0                   3200.0        2006.0
# 947                 11600.0                 185800.0        2012.0
# 948                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 944  2.125594e+08
# 945  1.366418e+09
# 946  6.683440e+07
# 947  1.028545e+07
# 948  1.366418e+09
#
# [949 rows x 13 columns]

# %% [markdown]
# ### The "Category" variable
# - **`category`**: Category or niche of the channel<br>
#
# We will explore the **`category`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any observations that has null values for the **`category`** column.

# %%
# Check for null values in "category"
nullcategory_df = youtube_df[youtube_df["category"].isnull()]
nullcategory_df.head(10)
# Out:
#                                       Youtuber  subscribers (millions)  \
# 85                               Vlad v_______                    37.9
# 124                              BETER B______                    32.7
# 146                         Diana and Roma ESP                    30.7
# 152  _______________ ______ __________________                    30.4
# 201                                 D Billions                    26.2
# 239                            shfa show India                    24.2
# 240   Super JoJo - Nursery Rhymes & Kids Songs                    24.1
# 245                         Diana and Roma ARA                    24.1
# 294                       Vlad and Niki Arabic                    22.5
# 301                          Vlad and Niki ESP                    22.0
#
#      video views (millions) category  uploads               Country  \
# 85             23510.152352      NaN    515.0         United States
# 124            19180.039918      NaN   2738.0                Turkey
# 146            12355.992466      NaN    578.0         United States
# 152            17999.961915      NaN    532.0         United States
# 201            31977.463002      NaN    775.0         United States
# 239            15724.160183      NaN    469.0  United Arab Emirates
# 240              329.774870      NaN     36.0         United States
# 245            11041.261296      NaN    590.0         United States
# 294            10613.701948      NaN    526.0         United States
# 301             8594.440895      NaN    515.0         United States
#
#       channel_type  lowest_monthly_earnings  highest_monthly_earnings  \
# 85   Entertainment                  61000.0                  976400.0
# 124          Games                 365900.0                 5900000.0
# 146  Entertainment                  25700.0                  412000.0
# 152  Entertainment                  30700.0                  491700.0
# 201  Entertainment                 121800.0                 1900000.0
# 239         People                  37800.0                  604800.0
# 240      Education                  82100.0                 1300000.0
# 245  Entertainment                  16700.0                  267500.0
# 294  Entertainment                  16300.0                  260300.0
# 301  Entertainment                  46000.0                  735500.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 85                 732300.0               11700000.0        2018.0
# 124               4400000.0               70200000.0        2012.0
# 146                309000.0                4900000.0        2016.0
# 152                368800.0                5900000.0        2018.0
# 201               1500000.0               23400000.0        2019.0
# 239                453600.0                7300000.0        2019.0
# 240                985500.0               15800000.0        2019.0
# 245                200700.0                3200000.0        2019.0
# 294                195200.0                3100000.0        2018.0
# 301                551600.0                8800000.0        2018.0
#
#       Population
# 85   328239523.0
# 124   83429615.0
# 146  328239523.0
# 152  328239523.0
# 201  328239523.0
# 239    9770529.0
# 240  328239523.0
# 245  328239523.0
# 294  328239523.0
# 301  328239523.0

# %%
# Display the counts
null_category_count = youtube_df['category'].isnull().sum()
print(f'Number of null values in "category": {null_category_count}')
# Out:
# Number of null values in "category": 39

# %% [markdown]
# We will now check for possible values we can use to replace the null values within the **`category`** column based on the **`channel_type`** column.<br>
# We are replacing the null values instead of removing them due to the presence of the **`channel_type`** variable which is similar in nature.

# %%
# Displaying the 'category' and 'channel_type' values for cleaning
column1 = 'category'
column2 = 'channel_type'

categoryandchannel_df = youtube_df.dropna(subset=[column1, column2])

unique_values_column1 = categoryandchannel_df[column1].unique().tolist()
unique_values_column2 = categoryandchannel_df[column2].unique().tolist()

df_unique_values_column1 = pd.DataFrame(unique_values_column1, columns=[column1])
df_unique_values_column2 = pd.DataFrame(unique_values_column2, columns=[column2])

# Concatenate DataFrames horizontally
result_df = pd.concat([df_unique_values_column1, df_unique_values_column2], axis=1)
result_df
# Out:
#                  category   channel_type
# 0                   Music          Music
# 1           Entertainment  Entertainment
# 2               Education      Education
# 3                   Shows         People
# 4          People & Blogs         Sports
# 5                  Gaming           Film
# 6                  Sports           News
# 7        Film & Animation          Games
# 8           Howto & Style         Comedy
# 9         News & Politics          Howto
# 10                 Comedy      Nonprofit
# 11               Trailers          Autos
# 12  Nonprofits & Activism           Tech
# 13   Science & Technology        Animals
# 14                 Movies            NaN
# 15         Pets & Animals            NaN
# 16       Autos & Vehicles            NaN
# 17        Travel & Events            NaN

# %% [markdown]
# After going through the unique values, we have prepared the following values to be used as replacement based on the **`channel_type`**.
# | channel_type | category |
# | ----------- | ----------- |
# | Games      | Gaming       |
# | People   | People & Blogs        |
# | Entertainment      | Entertainment       |
# | Sports   | Sports        |
# | Film      | Film & Animation       |
# | Howto   | Howto & Style        |
# | Education      | Education       |
# | Tech   | Science & Technology        |
# | Music   | Music    |
#
# For the remaining rows with neither **`category`** nor **`channel_type`** values, they will be removed.

# %%
# Replace category null values with closest value in channel_type

# Use the .loc method to set the new value based on the condition (where 'category' is null)
youtube_df.loc[(youtube_df['channel_type'] == 'Games') & (youtube_df['category'].isnull()), 'category'] = 'Gaming'
youtube_df.loc[(youtube_df['channel_type'] == 'People') & (youtube_df['category'].isnull()), 'category'] = 'People & Blogs'
youtube_df.loc[(youtube_df['channel_type'] == 'Entertainment') & (youtube_df['category'].isnull()), 'category'] = 'Entertainment'
youtube_df.loc[(youtube_df['channel_type'] == 'Sports') & (youtube_df['category'].isnull()), 'category'] = 'Sports'
youtube_df.loc[(youtube_df['channel_type'] == 'Film') & (youtube_df['category'].isnull()), 'category'] = 'Film & Animation'
youtube_df.loc[(youtube_df['channel_type'] == 'Howto') & (youtube_df['category'].isnull()), 'category'] = 'Howto & Style'
youtube_df.loc[(youtube_df['channel_type'] == 'Education') & (youtube_df['category'].isnull()), 'category'] = 'Education'
youtube_df.loc[(youtube_df['channel_type'] == 'Tech') & (youtube_df['category'].isnull()), 'category'] = 'Science & Technology'
youtube_df.loc[(youtube_df['channel_type'] == 'Music') & (youtube_df['category'].isnull()), 'category'] = 'Music'

# Drop remaining rows with null values for 'category' column
youtube_df.dropna(subset=['category'], inplace=True)

# Display the modified DataFrame
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 944               Natan por A__                    12.3
# 945    Free Fire India Official                    12.3
# 946                       Panda                    12.3
# 947                 RobTopGames                    12.3
# 948                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 944             9029.609749          Sports    1200.0          Brazil
# 945             1674.409945  People & Blogs    1500.0           India
# 946             2214.684303          Gaming    2452.0  United Kingdom
# 947              374.123483          Gaming      39.0          Sweden
# 948             2129.773714          Comedy      62.0           India
#
#       channel_type  lowest_monthly_earnings  highest_monthly_earnings  \
# 0            Music                 564600.0                 9000000.0
# 1    Entertainment                 337000.0                 5400000.0
# 2        Education                 493800.0                 7900000.0
# 3    Entertainment                 455900.0                 7300000.0
# 4    Entertainment                 182900.0                 2900000.0
# ..             ...                      ...                       ...
# 944  Entertainment                 138100.0                 2200000.0
# 945          Games                  16200.0                  258900.0
# 946          Games                     17.0                     268.0
# 947          Games                    968.0                   15500.0
# 948         Comedy                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 944               1700000.0               26500000.0        2017.0
# 945                194200.0                3100000.0        2018.0
# 946                   201.0                   3200.0        2006.0
# 947                 11600.0                 185800.0        2012.0
# 948                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 944  2.125594e+08
# 945  1.366418e+09
# 946  6.683440e+07
# 947  1.028545e+07
# 948  1.366418e+09
#
# [948 rows x 13 columns]

# %% [markdown]
# We will also drop the **`channel_type`** column since we will no longer be using it.

# %%
# Drop 'channel_type' column
youtube_df.drop(columns='channel_type', inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 944               Natan por A__                    12.3
# 945    Free Fire India Official                    12.3
# 946                       Panda                    12.3
# 947                 RobTopGames                    12.3
# 948                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 944             9029.609749          Sports    1200.0          Brazil
# 945             1674.409945  People & Blogs    1500.0           India
# 946             2214.684303          Gaming    2452.0  United Kingdom
# 947              374.123483          Gaming      39.0          Sweden
# 948             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 944                 138100.0                 2200000.0
# 945                  16200.0                  258900.0
# 946                     17.0                     268.0
# 947                    968.0                   15500.0
# 948                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 944               1700000.0               26500000.0        2017.0
# 945                194200.0                3100000.0        2018.0
# 946                   201.0                   3200.0        2006.0
# 947                 11600.0                 185800.0        2012.0
# 948                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 944  2.125594e+08
# 945  1.366418e+09
# 946  6.683440e+07
# 947  1.028545e+07
# 948  1.366418e+09
#
# [948 rows x 12 columns]

# %% [markdown]
# After removing the observations, we will be resetting the indexes ensure there are no gaps and the data remains continuous.

# %%
# Reset the index after dropping rows
youtube_df.reset_index(drop=True, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 943               Natan por A__                    12.3
# 944    Free Fire India Official                    12.3
# 945                       Panda                    12.3
# 946                 RobTopGames                    12.3
# 947                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 943             9029.609749          Sports    1200.0          Brazil
# 944             1674.409945  People & Blogs    1500.0           India
# 945             2214.684303          Gaming    2452.0  United Kingdom
# 946              374.123483          Gaming      39.0          Sweden
# 947             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 943                 138100.0                 2200000.0
# 944                  16200.0                  258900.0
# 945                     17.0                     268.0
# 946                    968.0                   15500.0
# 947                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 943               1700000.0               26500000.0        2017.0
# 944                194200.0                3100000.0        2018.0
# 945                   201.0                   3200.0        2006.0
# 946                 11600.0                 185800.0        2012.0
# 947                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 943  2.125594e+08
# 944  1.366418e+09
# 945  6.683440e+07
# 946  1.028545e+07
# 947  1.366418e+09
#
# [948 rows x 12 columns]

# %% [markdown]
# ### The "Country" variable
# - **`Country`**: Country where the YouTube channel originates<br>
#
# We will explore the **`Country`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any observations that has null values for the **`Country`** column.

# %%
# Check for null values in Country
null_country_df = youtube_df[youtube_df["Country"].isnull()]
null_country_df.head(10)
# Out:
#                                              Youtuber  subscribers (millions)  \
# 11                                          Goldmines                    86.9
# 34  LooLoo Kids - Nursery Rhymes and Children's Songs                    54.0
# 44                                            Badabun                    46.8
# 47                                          Bad Bunny                    46.1
# 57                                     HolaSoyGerman.                    43.6
# 68                                        elrubiusOMG                    40.4
# 69                                    Toys and Colors                    40.3
# 71                          LUCCAS NETO - LUCCAS TOON                    39.4
# 94                                       PowerKids TV                    36.5
# 96                                              Ozuna                    36.2
#
#     video views (millions)          category  uploads Country  \
# 11            24118.230580  Film & Animation      1.0     NaN
# 34            32312.431239             Music     11.0     NaN
# 44            19398.045702     Entertainment      1.0     NaN
# 47            30686.342319             Music      1.0     NaN
# 57             4831.311245     Entertainment      6.0     NaN
# 68             7410.536668            Gaming    703.0     NaN
# 69            47005.053156     Entertainment      4.0     NaN
# 71            22302.547082    People & Blogs      1.0     NaN
# 94            18961.241905  Film & Animation   5621.0     NaN
# 96            23355.801606             Music    196.0     NaN
#
#     lowest_monthly_earnings  highest_monthly_earnings  lowest_yearly_earnings  \
# 11                     0.00                      0.07                    0.05
# 34                     0.04                      0.64                    0.48
# 44                     0.11                      2.00                    1.00
# 47                     0.00                      0.00                    0.00
# 57                     0.00                      0.02                    0.01
# 68                  1400.00                  23100.00                17300.00
# 69                     0.00                      0.02                    0.02
# 71                     0.00                      0.01                    0.01
# 94                 79700.00                1300000.00               956100.00
# 96                 42300.00                 677000.00               507700.00
#
#     highest_yearly_earnings  created_year  Population
# 11                     0.86        2006.0         NaN
# 34                     8.00        2016.0         NaN
# 44                    21.00        2007.0         NaN
# 47                     0.05        2005.0         NaN
# 57                     0.19        2016.0         NaN
# 68                277100.00        2011.0         NaN
# 69                     0.24        2018.0         NaN
# 71                     0.10        2021.0         NaN
# 94              15300000.00        2014.0         NaN
# 96               8100000.00        2016.0         NaN

# %%
# Check for null values in Country
null_country_count = youtube_df["Country"].isnull().sum()
print(f'Number of null values in "Country": {null_country_count}')
# Out:
# Number of null values in "Country": 94

# %% [markdown]
# There are 94 observations without a country, approximately 10% of the dataset has null **`Country`** values.<br>
# Next, we will look for possible misrepresentations of the data.

# %%
# Get the unique values in the "Country" column
unique_country = youtube_df['Country'].unique()
print(unique_country)
print(f"Number of countries: {unique_country.__len__()}")
# Out:
# ['India' 'United States' 'Japan' 'Russia' 'South Korea' nan
#  'United Kingdom' 'Canada' 'Brazil' 'Argentina' 'Chile' 'Cuba'
#  'El Salvador' 'Pakistan' 'Philippines' 'Thailand' 'Colombia' 'Barbados'
#  'Mexico' 'United Arab Emirates' 'Spain' 'Saudi Arabia' 'Indonesia'
#  'Turkey' 'Venezuela' 'Kuwait' 'Jordan' 'Netherlands' 'Australia' 'Italy'
#  'Germany' 'France' 'Sweden' 'Ukraine' 'Latvia' 'Switzerland' 'Vietnam'
#  'Malaysia' 'China' 'Iraq' 'Singapore' 'Egypt' 'Andorra' 'Ecuador'
#  'Morocco' 'Peru' 'Bangladesh' 'Finland' 'Samoa']
# Number of countries: 49

# %% [markdown]
# Since there are no misrepresentations, we will check the count for each unique value and determine if its possible to use the mode as replacement for the missing values.

# %%
# Get the count of each unique value in the "Country" column
country_counts = youtube_df['Country'].value_counts()

# Display the count of each unique value
print("Count of each unique value in 'Country':")
print(country_counts)
# Out:
# Count of each unique value in 'Country':
# Country
# United States           306
# India                   167
# Brazil                   61
# United Kingdom           43
# Mexico                   30
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   15
# Canada                   14
# Argentina                13
# Philippines              12
# Colombia                 11
# Ukraine                   8
# Australia                 8
# Saudi Arabia              8
# United Arab Emirates      7
# Pakistan                  6
# Japan                     5
# France                    5
# Germany                   5
# Sweden                    4
# Turkey                    4
# Jordan                    3
# Netherlands               3
# Chile                     3
# Vietnam                   3
# Iraq                      2
# Italy                     2
# Ecuador                   2
# Egypt                     2
# Singapore                 2
# Morocco                   1
# Peru                      1
# Bangladesh                1
# Finland                   1
# Andorra                   1
# Kuwait                    1
# China                     1
# Malaysia                  1
# Switzerland               1
# Latvia                    1
# Venezuela                 1
# Barbados                  1
# El Salvador               1
# Cuba                      1
# Samoa                     1
# Name: count, dtype: int64

# %% [markdown]
# The mode value **`United States`** has 306 counts, approximately 32.27% of Youtubers in the dataset are from the **`United States`**.<br>
# We will not replace missing values with the mode value since there is a large number of unique values in the dataset and the mode already represents a significant portion of the data. <br>
# If replaced, it can lead to a lack of diversity in the dataset, and it may not accurately reflect the underlying data distribution.

# %% [markdown]
#     For visualization, if replaced we can see the following distribution of the values below.

# %%
# Replace missing values with the mode
test_df = youtube_df.copy()

test_df['Country'].fillna(test_df['Country'].mode()[0], inplace=True)

# Create a countplot to show the distribution of 'country' values
plt.figure(figsize=(10, 5))
sns.countplot(data=test_df, x='Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Distribution of Country Values')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %% [markdown]
# We will be removing the observations with null **`Country`** values.

# %%
# Drop observations with null values
youtube_df.dropna(subset=['Country'], inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 943               Natan por A__                    12.3
# 944    Free Fire India Official                    12.3
# 945                       Panda                    12.3
# 946                 RobTopGames                    12.3
# 947                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 943             9029.609749          Sports    1200.0          Brazil
# 944             1674.409945  People & Blogs    1500.0           India
# 945             2214.684303          Gaming    2452.0  United Kingdom
# 946              374.123483          Gaming      39.0          Sweden
# 947             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 943                 138100.0                 2200000.0
# 944                  16200.0                  258900.0
# 945                     17.0                     268.0
# 946                    968.0                   15500.0
# 947                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 943               1700000.0               26500000.0        2017.0
# 944                194200.0                3100000.0        2018.0
# 945                   201.0                   3200.0        2006.0
# 946                 11600.0                 185800.0        2012.0
# 947                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 943  2.125594e+08
# 944  1.366418e+09
# 945  6.683440e+07
# 946  1.028545e+07
# 947  1.366418e+09
#
# [854 rows x 12 columns]

# %% [markdown]
# After removing the observations, we will be resetting the indexes ensure there are no gaps and the data remains continuous.

# %%
# Reset the index after dropping rows
youtube_df.reset_index(drop=True, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 849               Natan por A__                    12.3
# 850    Free Fire India Official                    12.3
# 851                       Panda                    12.3
# 852                 RobTopGames                    12.3
# 853                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 849             9029.609749          Sports    1200.0          Brazil
# 850             1674.409945  People & Blogs    1500.0           India
# 851             2214.684303          Gaming    2452.0  United Kingdom
# 852              374.123483          Gaming      39.0          Sweden
# 853             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 849                 138100.0                 2200000.0
# 850                  16200.0                  258900.0
# 851                     17.0                     268.0
# 852                    968.0                   15500.0
# 853                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 849               1700000.0               26500000.0        2017.0
# 850                194200.0                3100000.0        2018.0
# 851                   201.0                   3200.0        2006.0
# 852                 11600.0                 185800.0        2012.0
# 853                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 849  2.125594e+08
# 850  1.366418e+09
# 851  6.683440e+07
# 852  1.028545e+07
# 853  1.366418e+09
#
# [854 rows x 12 columns]

# %% [markdown]
# ### The "Lowest Monthly Earnings" variable
# - **`lowest_monthly_earnings`**: Lowest estimated monthly earnings from the channel \$<br>
#
# We will explore the **`lowest_monthly_earnings`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for **`lowest_monthly_earnings`** that are zero (0) or null.

# %%
# Check for null values in lowest_monthly_earnings
null_lowestmonthly_df = youtube_df[youtube_df["lowest_monthly_earnings"].eq(0)]
null_lowestmonthly_df.head(10)
# Out:
#                                    Youtuber  subscribers (millions)  \
# 12                          5-Minute Crafts                    80.1
# 18                          Canal KondZilla                    66.5
# 22                    T-Series Bhakti Sagar                    61.0
# 85                          Ultra Bollywood                    36.6
# 103                             Ch3Thailand                    33.5
# 127  The Tonight Show Starring Jimmy Fallon                    31.2
# 139                             Talking Tom                    30.2
# 146                                  Maluma                    29.3
# 147                                   Zhong                    29.2
# 159                               MrBeast 2                    27.5
#
#      video views (millions)        category  uploads         Country  \
# 12             26236.790209   Howto & Style      1.0  United Kingdom
# 18             36775.585925           Music   2572.0          Brazil
# 22             29533.230328           Music     13.0           India
# 85             15653.786446        Trailers   9168.0           India
# 103            29611.914495   Entertainment  96214.0        Thailand
# 127            17111.726160          Comedy   8976.0   United States
# 139            15199.330166          Comedy      2.0   United States
# 146            21226.945136           Music     14.0       Argentina
# 147            14727.238483   Entertainment   1513.0   United States
# 159             4552.581106  People & Blogs     27.0   United States
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 12                       0.0                      0.00
# 18                       0.0                      0.00
# 22                       0.0                      0.04
# 85                       0.0                      0.00
# 103                      0.0                      0.00
# 127                      0.0                      0.00
# 139                      0.0                      0.00
# 146                      0.0                      0.06
# 147                      0.0                      0.00
# 159                      0.0                      0.00
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 12                     0.00                     0.05        2020.0
# 18                     0.00                     0.00        2012.0
# 22                     0.03                     0.48        2018.0
# 85                     0.00                     0.00        2009.0
# 103                    0.00                     0.00        2014.0
# 127                    0.00                     0.00        2006.0
# 139                    0.00                     0.00        2008.0
# 146                    0.05                     0.72        2015.0
# 147                    0.00                     0.00        2015.0
# 159                    0.00                     0.00        2011.0
#
#        Population
# 12   6.683440e+07
# 18   2.125594e+08
# 22   1.366418e+09
# 85   1.366418e+09
# 103  6.962558e+07
# 127  3.282395e+08
# 139  3.282395e+08
# 146  4.493871e+07
# 147  3.282395e+08
# 159  3.282395e+08

# %%
# Display the count
null_lowestmonthly_count = youtube_df["lowest_monthly_earnings"].eq(0).sum()
print(f'Number of null values in "lowest_monthly_earnings": {null_lowestmonthly_count}')
# Out:
# Number of null values in "lowest_monthly_earnings": 34

# %% [markdown]
# We have 34 observations wherein they have zero (0) or null values for **`lowest_monthly_earnings`**.<br><br>
# Since there is the possibility of the earnings coming from sponsorships, affiliate marketing, etc., some of the earnings may not be accurated particularly the null values.
# We will be removing these zero (0) or null values to maintain the overall quality and integrity of our dataset. Through removal, we can avoid distorting the underlying patterns in the data and also avoid the complications of imputations. We would still be able to perform a meaningful analysis despite reducing the dataset.

# %%
# Drop all observations with zero lowest_monthly_earnings
youtube_df.drop(youtube_df[youtube_df["lowest_monthly_earnings"].eq(0)].index, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 849               Natan por A__                    12.3
# 850    Free Fire India Official                    12.3
# 851                       Panda                    12.3
# 852                 RobTopGames                    12.3
# 853                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 849             9029.609749          Sports    1200.0          Brazil
# 850             1674.409945  People & Blogs    1500.0           India
# 851             2214.684303          Gaming    2452.0  United Kingdom
# 852              374.123483          Gaming      39.0          Sweden
# 853             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 849                 138100.0                 2200000.0
# 850                  16200.0                  258900.0
# 851                     17.0                     268.0
# 852                    968.0                   15500.0
# 853                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 849               1700000.0               26500000.0        2017.0
# 850                194200.0                3100000.0        2018.0
# 851                   201.0                   3200.0        2006.0
# 852                 11600.0                 185800.0        2012.0
# 853                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 849  2.125594e+08
# 850  1.366418e+09
# 851  6.683440e+07
# 852  1.028545e+07
# 853  1.366418e+09
#
# [820 rows x 12 columns]

# %% [markdown]
# After removing the observations, we will be resetting the indexes ensure there are no gaps and the data remains continuous.

# %%
# Reset the index after dropping rows
youtube_df.reset_index(drop=True, inplace=True)
youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 815               Natan por A__                    12.3
# 816    Free Fire India Official                    12.3
# 817                       Panda                    12.3
# 818                 RobTopGames                    12.3
# 819                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 815             9029.609749          Sports    1200.0          Brazil
# 816             1674.409945  People & Blogs    1500.0           India
# 817             2214.684303          Gaming    2452.0  United Kingdom
# 818              374.123483          Gaming      39.0          Sweden
# 819             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 815                 138100.0                 2200000.0
# 816                  16200.0                  258900.0
# 817                     17.0                     268.0
# 818                    968.0                   15500.0
# 819                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 815               1700000.0               26500000.0        2017.0
# 816                194200.0                3100000.0        2018.0
# 817                   201.0                   3200.0        2006.0
# 818                 11600.0                 185800.0        2012.0
# 819                 72000.0                1200000.0        2017.0
#
#        Population
# 0    1.366418e+09
# 1    3.282395e+08
# 2    3.282395e+08
# 3    1.366418e+09
# 4    3.282395e+08
# ..            ...
# 815  2.125594e+08
# 816  1.366418e+09
# 817  6.683440e+07
# 818  1.028545e+07
# 819  1.366418e+09
#
# [820 rows x 12 columns]

# %% [markdown]
# We will not be performing any preprocessing in terms of removing outliers as it is possible for channel to have no "earnings" or very high "earnings".

# %% [markdown]
# ### The "Highest Monthly Earnings" variable
# - **`highest_monthly_earnings`**: Highest estimated monthly earnings from the channel \$<br>
#
# We will explore the **`highest_monthly_earnings`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for **`highest_monthly_earnings`** that are zero (0) or null.

# %%
# Check for null values in highest_monthly_earnings
null_highestmonthly_df = youtube_df[youtube_df["highest_monthly_earnings"].eq(0)]
null_highestmonthly_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Youtuber, subscribers (millions), video views (millions), category, uploads, Country, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, created_year, Population]
# Index: []

# %%
# Display the count
null_highestmonthly_count = youtube_df["highest_monthly_earnings"].eq(0).sum()
print(f'Number of null values in "highest_monthly_earnings": {null_highestmonthly_count}')
# Out:
# Number of null values in "highest_monthly_earnings": 0

# %% [markdown]
# We have 0 observations wherein they have zero (0) or null values for **`highest_monthly_earnings`**.
#
# There is no need to drop any observations.

# %% [markdown]
# ### The "Lowest Yearly Earnings" variable
# - **`lowest_yearly_earnings`**: Lowest estimated yearly earnings from the channel \$<br>
#
# We will explore the **`lowest_yearly_earnings`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for **`lowest_yearly_earnings`** that are zero (0) or null.

# %%
# Check for null values in lowest_yearly_earnings
null_lowestyearly_df = youtube_df[youtube_df["lowest_yearly_earnings"].eq(0)]
null_lowestyearly_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Youtuber, subscribers (millions), video views (millions), category, uploads, Country, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, created_year, Population]
# Index: []

# %%
# Display the count
null_lowestyearly_count = youtube_df["lowest_yearly_earnings"].eq(0).sum()
print(f'Number of null values in "lowest_yearly_earnings": {null_lowestyearly_count}')
# Out:
# Number of null values in "lowest_yearly_earnings": 0

# %% [markdown]
# We have 0 observations wherein they have zero (0) or null values for **`lowest_yearly_earnings`**.
#
# There is no need to drop any observations.

# %% [markdown]
# ### The "Highest Yearly Earnings" variable
# - **`highest_yearly_earnings`**: Highest estimated monthly earnings from the channel \$<br>
#
# We will explore the **`highest_yearly_earnings`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for **`highest_yearly_earnings`** that are zero (0) or null.

# %%
# Check for null values in highest_yearly_earnings
null_highestyearly_df = youtube_df[youtube_df["highest_yearly_earnings"].eq(0)]
null_highestyearly_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Youtuber, subscribers (millions), video views (millions), category, uploads, Country, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, created_year, Population]
# Index: []

# %%
# Display the count
null_highestyearly_count = youtube_df["highest_yearly_earnings"].eq(0).sum()
print(f'Number of null values in "highest_yearly_earnings": {null_highestyearly_count}')
# Out:
# Number of null values in "highest_yearly_earnings": 0

# %% [markdown]
# We have 0 observations wherein they have zero (0) or null values for **`highest_yearly_earnings`**. There is no need for cleaning.

# %% [markdown]
# ### The "Created Year" variable
# - **`created_year`**: Year when the YouTube channel was created<br>
#
# We will explore the **`created_year`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for **`created_year`** that are zero (0) or null.

# %%
# Check for null values in created_year
null_createdyear_df = youtube_df[youtube_df["created_year"].eq(0)]
null_createdyear_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Youtuber, subscribers (millions), video views (millions), category, uploads, Country, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, created_year, Population]
# Index: []

# %%
# Display the count
null_createdyear_count = youtube_df["created_year"].eq(0).sum()
print(f'Number of null values in "created_year": {null_createdyear_count}')
# Out:
# Number of null values in "created_year": 0

# %% [markdown]
# We also want to check if there are any values less than 2005 since Youtube was made in this year.

# %%
# Check if there are any observations of Youtube channels created before 2005
subset = youtube_df[youtube_df['created_year'] < 2005]
subset
# Out:
#    Youtuber  subscribers (millions)  video views (millions)         category  \
# 82  YouTube                    36.3             3010.784935  News & Politics
#
#     uploads        Country  lowest_monthly_earnings  highest_monthly_earnings  \
# 82    744.0  United States                   5300.0                   84400.0
#
#     lowest_yearly_earnings  highest_yearly_earnings  created_year   Population
# 82                 63300.0                1000000.0        1970.0  328239523.0

# %% [markdown]
# After manual checking, the channel does exist and the year shown is accurate but it may have been an error or a default value (0) in Posix time assigned in the database.
#
# As we are dealing with years, we will remove the observation instead since incorrect or error values for a year can significantly affect the accuracy and interpretation of the data.

# %%
# Get the index of the subset
indices_to_drop = subset.index

# Drop the observations from the original DataFrame
youtube_df.drop(indices_to_drop, inplace=True)

# %% [markdown]
# ### The "Population" variable
# - **`Population`**: Total population of the country<br>
#
# We will explore the  **`Population`** column and check if it needs any cleaning or preprocessing.

# %% [markdown]
# We want to check if there are any values for  **`Population`** that are zero (0) or null.

# %%
# Check for null values in Population
null_population_df = youtube_df[youtube_df["Population"].eq(0)]
null_population_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Youtuber, subscribers (millions), video views (millions), category, uploads, Country, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, created_year, Population]
# Index: []

# %%
# Display the count
null_population_count = youtube_df["Population"].eq(0).sum()
print(f'Number of null values in "Population": {null_population_count}')
# Out:
# Number of null values in "Population": 0

# %%
# Check for NaN values in the 'Population' column
nan_subscribers = youtube_df['Population'].isna().sum()
print("Number of NaN values in 'Population' column:", nan_subscribers)
# Out:
# Number of NaN values in 'Population' column: 1

# %% [markdown]
# We have 1 observations wherein they have a NaN value for **`Population`**. We will drop this observation.

# %%
# Drop rows with NaN values in 'Population' column
youtube_df.dropna(subset=['Population'], inplace=True)

# %% [markdown]
# We want to scale the values to millions to make it easier to interpret and visualize.

# %%
# Convert the "Population" column to values in millions
youtube_df['Population'] = youtube_df['Population'] / 1000000
# # Rename the "Population" column to indicate values are in millions
youtube_df = youtube_df.rename(columns={'Population': 'Population (millions)'})
# Round the values to 3 decimal places
youtube_df['Population (millions)'] = youtube_df['Population (millions)'].round(3)

youtube_df
# Out:
#                        Youtuber  subscribers (millions)  \
# 0                      T-Series                   245.0
# 1                       MrBeast                   166.0
# 2    Cocomelon - Nursery Rhymes                   162.0
# 3                     SET India                   159.0
# 4           ___ Kids Diana Show                   112.0
# ..                          ...                     ...
# 815               Natan por A__                    12.3
# 816    Free Fire India Official                    12.3
# 817                       Panda                    12.3
# 818                 RobTopGames                    12.3
# 819                Make Joke Of                    12.3
#
#      video views (millions)        category   uploads         Country  \
# 0             228000.000000           Music   20082.0           India
# 1              28368.841870   Entertainment     741.0   United States
# 2             164000.000000       Education     966.0   United States
# 3             148000.000000           Shows  116536.0           India
# 4              93247.040539  People & Blogs    1111.0   United States
# ..                      ...             ...       ...             ...
# 815             9029.609749          Sports    1200.0          Brazil
# 816             1674.409945  People & Blogs    1500.0           India
# 817             2214.684303          Gaming    2452.0  United Kingdom
# 818              374.123483          Gaming      39.0          Sweden
# 819             2129.773714          Comedy      62.0           India
#
#      lowest_monthly_earnings  highest_monthly_earnings  \
# 0                   564600.0                 9000000.0
# 1                   337000.0                 5400000.0
# 2                   493800.0                 7900000.0
# 3                   455900.0                 7300000.0
# 4                   182900.0                 2900000.0
# ..                       ...                       ...
# 815                 138100.0                 2200000.0
# 816                  16200.0                  258900.0
# 817                     17.0                     268.0
# 818                    968.0                   15500.0
# 819                   6000.0                   96000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  created_year  \
# 0                 6800000.0              108400000.0        2006.0
# 1                 4000000.0               64700000.0        2012.0
# 2                 5900000.0               94800000.0        2006.0
# 3                 5500000.0               87500000.0        2006.0
# 4                 2200000.0               35100000.0        2015.0
# ..                      ...                      ...           ...
# 815               1700000.0               26500000.0        2017.0
# 816                194200.0                3100000.0        2018.0
# 817                   201.0                   3200.0        2006.0
# 818                 11600.0                 185800.0        2012.0
# 819                 72000.0                1200000.0        2017.0
#
#      Population (millions)
# 0                 1366.418
# 1                  328.240
# 2                  328.240
# 3                 1366.418
# 4                  328.240
# ..                     ...
# 815                212.559
# 816               1366.418
# 817                 66.834
# 818                 10.285
# 819               1366.418
#
# [818 rows x 12 columns]

# %% [markdown]
# The **`Population`** column is renamed to **`Population (millions)`** to represent the scaling.

# %% [markdown]
# ### Check Data Types of the Values in each Column
#
# We want to check if the values in each column match their respective data types **`float64`**, **`int64`**, and **`object`**.

# %%
# Define the expected data types
expected_data_types = {
    'Youtuber': object,
    'subscribers (millions)': float,
    'video views (millions)': float,
    'uploads': float,
    'Country': object,
    'lowest_monthly_earnings': float,
    'highest_monthly_earnings': float,
    'lowest_yearly_earnings': float,
    'highest_yearly_earnings': float,
    'created_year': float,
    'Population (millions)': float
}

# Check if values in each column match the expected data type using a custom function
def check_data_type(column_name, expected_dtype):
    for value in youtube_df[column_name]:
        if not isinstance(value, expected_dtype):
            return False
    return True

all_columns_match = True

for column_name, expected_dtype in expected_data_types.items():
    if not check_data_type(column_name, expected_dtype):
        all_columns_match = False
        print(f"Column '{column_name}' does not match the expected data type {expected_dtype}.")

if all_columns_match:
    print("All columns match the expected data types.")
else:
    print("Not all columns match the expected data types.")
# Out:
# All columns match the expected data types.

# %% [markdown]
# ### Post Data Cleaning

# %% [markdown]
# #### Dataset Information:
# - **`Rows/Observations`**: 820
# - **`Variables/Columns`**: 12
# - **`Data Types`**: float64(9), object(3)
#
# The variables that will be used are as follows:
# - **`Youtuber`**: Name of the YouTube channel
# - **`subscribers (millions)`**: Number of subscribers to the channel
# - **`video views (millions)`**: Overall count views to the channel
# - **`category`**: Category or niche of the channel
# - **`uploads`**: Total number of videos uploaded on the channel
# - **`Country`**: Country where the YouTube channel originates
# - **`lowest_monthly_earnings`**: Lowest estimated monthly earnings from the channel \$
# - **`highest_monthly_earnings`**: Highest estimated monthly earnings from the channel \$
# - **`lowest_yearly_earnings`**: Lowest estimated yearly earnings from the channel \$
# - **`highest_yearly_earnings`**: Highest estimated yearly earnings from the channel $
# - **`created_year`**: Year when the YouTube channel was created
# - **`Population (millions)`**: Total population of the country

# %%
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 818 entries, 0 to 819
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Youtuber                  818 non-null    object
#  1   subscribers (millions)    818 non-null    float64
#  2   video views (millions)    818 non-null    float64
#  3   category                  818 non-null    object
#  4   uploads                   818 non-null    float64
#  5   Country                   818 non-null    object
#  6   lowest_monthly_earnings   818 non-null    float64
#  7   highest_monthly_earnings  818 non-null    float64
#  8   lowest_yearly_earnings    818 non-null    float64
#  9   highest_yearly_earnings   818 non-null    float64
#  10  created_year              818 non-null    float64
#  11  Population (millions)     818 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 83.1+ KB

# %% [markdown]
# # Exploratory Data Analysis
#     This section of the Jupyter Notebook contains the overall process of our Exploratory Data Analysis of our dataset, together with the questions that we are curious to comprehend and answer through exploratory data analysis.

# %% [markdown]
# ### 1. What are the lowest and highest yearly earning categories?
#
# **Description**:
# - This analysis aims to identify and explore the YouTube content categories or niches that yield the lowest and highest yearly earnings.
#
# **Variables**:
# - `category`
# - `lowest_yearly_earnings`
# - `highest_yearly_earnings`

# %% [markdown]
# **Numerical Summary**
#
# Get the lowest and highest yearly earnings of Youtube Channels per category.
# Calculate the average yearly earnings for reference as well.

# %%
# calculate the average yearly earnings
youtube_df['average_yearly_earnings'] = (youtube_df['lowest_yearly_earnings'] + youtube_df['highest_yearly_earnings']) / 2

average_category_means = youtube_df.groupby('category')['average_yearly_earnings'].mean()

# Sort the categories by mean earnings in descending order
average_category_means = average_category_means.sort_values(ascending=False)

# Display the sorted categories and their mean earnings
average_category_means
# Out:
# category
# Shows                    1.403500e+07
# Pets & Animals           1.018330e+07
# Autos & Vehicles         6.994875e+06
# Movies                   5.791050e+06
# Sports                   5.699938e+06
# Film & Animation         5.161399e+06
# People & Blogs           5.084952e+06
# Comedy                   4.904557e+06
# Education                4.842036e+06
# Trailers                 4.621400e+06
# News & Politics          4.414874e+06
# Entertainment            4.382589e+06
# Music                    3.963591e+06
# Nonprofits & Activism    2.496375e+06
# Gaming                   2.390513e+06
# Science & Technology     1.444530e+06
# Howto & Style            9.978287e+05
# Travel & Events          7.965000e+05
# Name: average_yearly_earnings, dtype: float64

# %% [markdown]
# **Visualization**
#
# Create a horizontal bar chart to visualize the lowest and highest yearly earnings categories, showing how they compare to one another.

# %%
# make category as string
youtube_df['category'] = youtube_df['category'].astype(str)

# create horizontal bar chart for lowest yearly earnings sorted 
plt.figure(figsize=(10, 6))
sns.barplot(data=youtube_df.sort_values(by='lowest_yearly_earnings', ascending=False),
            x='lowest_yearly_earnings', y='category')
plt.xlabel('Lowest Yearly Earnings')
plt.ylabel('Category')
plt.title('Lowest Yearly Earnings by Category')
plt.show()

# create horizontal bar chart for highest yearly earnings sorted 
plt.figure(figsize=(10, 6))
sns.barplot(data=youtube_df.sort_values(by='highest_yearly_earnings', ascending=False),
            x='highest_yearly_earnings', y='category')
plt.xlabel('Highest Yearly Earnings')
plt.ylabel('Category')
plt.title('Highest Yearly Earnings by Category')
plt.show()

# create horizontal bar chart for average yearly earnings sorted 
plt.figure(figsize=(10, 6))
sns.barplot(data=youtube_df.sort_values(by='average_yearly_earnings', ascending=False),
            x='average_yearly_earnings', y='category')
plt.xlabel('Average Yearly Earnings')
plt.ylabel('Category')
plt.title('Average Yearly Earnings by Category')
plt.show()

# %% [markdown]
# **Conclusion**
#
# The 'Show' category stands out as the highest-earning category, boasting an impressive average yearly earning of 14,035,000. Following closely, the 'Pets and Animals' category commands a solid average earning of 10,183,300. In contrast, the 'Travel & Events' and 'Howto & Style' categories exhibit comparatively lower average yearly earnings, with figures of 796,500 and 968,481, respectively. These findings shed light on the financial dynamics of different content categories on YouTube, with 'Show' and 'Pets and Animals' leading the way in terms of earnings.

# %%
# mean of shows category 
youtube_df[youtube_df['category'] == 'Shows']['average_yearly_earnings'].describe()
# Out:
# count    1.200000e+01
# mean     1.403500e+07
# std      1.651094e+07
# min      1.434800e+06
# 25%      2.457462e+06
# 50%      5.231925e+06
# 75%      2.040000e+07
# max      4.650000e+07
# Name: average_yearly_earnings, dtype: float64

# %%
# mean of travels & events category
youtube_df[youtube_df['category'] == 'Travel & Events']['average_yearly_earnings'].describe()
# Out:
# count         1.0
# mean     796500.0
# std           NaN
# min      796500.0
# 25%      796500.0
# 50%      796500.0
# 75%      796500.0
# max      796500.0
# Name: average_yearly_earnings, dtype: float64

# %%
# mean of pets & animals category
youtube_df[youtube_df['category'] == 'Pets & Animals']['average_yearly_earnings'].describe()
# Out:
# count    2.000000e+00
# mean     1.018330e+07
# std      1.282225e+07
# min      1.116600e+06
# 25%      5.649950e+06
# 50%      1.018330e+07
# 75%      1.471665e+07
# max      1.925000e+07
# Name: average_yearly_earnings, dtype: float64

# %%
# mean of howto & style category
youtube_df[youtube_df['category'] == 'Howto & Style']['average_yearly_earnings'].describe()
# Out:
# count    3.300000e+01
# mean     9.978287e+05
# std      1.083816e+06
# min      1.648000e+03
# 25%      3.697000e+05
# 50%      6.900000e+05
# 75%      1.115800e+06
# max      4.941900e+06
# Name: average_yearly_earnings, dtype: float64

# %% [markdown]
# ### 2. Is there a correlation between video views and subscriber counts on YouTube channels?
#
# **Description**
# - This analysis investigates the relationship between the number of video views and the number of subscribers on YouTube channels to determine if there's a correlation indicating viewer engagement.
#
# **Variables**
# - `video views`
# - `subscribers`

# %% [markdown]
# **Numerical Summary**
#
# Calculate the Pearson correlation coefficient to quantify the strength and direction of the correlation between video views and subscribers.

# %%
# calculate pearson correlation betwen video views and subscribers
youtube_df['video views (millions)'].corr(youtube_df['subscribers (millions)'])
# Out:
# 0.8403978233213484

# %% [markdown]
# **Visualization**
#
# Create a scatterplot to visualize the relationship between video views and subscribers, indicating the nature of the correlation.

# %%
# scatterplot by using
plt.figure(figsize=(16, 8))
sns.scatterplot(x='video views (millions)', y='subscribers (millions)', data=youtube_df)
plt.xlabel('Video Views')
plt.ylabel('Subscribers')
plt.title('Video Views vs. Subscribers')
plt.show()

# %% [markdown]
# **Conclusion**
#
# The Pearson correlation value produced by the relationship between video views and subscriber count was 0.7509576173780214, and since the r value greater than 0.5, there is a strong relationship and a positive correlation between the video views and the subscriber count of a Youtube Channel.

# %% [markdown]
# ### 3. Is there a correlation between video views and average yearly earnings on YouTube channels?
#
# **Description**
# - This analysis explores whether there's a correlation between the number of video views and the monthly earnings of YouTube channels, offering insights into the monetization potential of views.
#
# **Variables**
# - `video views`
# - `lowest_yearly_earnings`
# - `highest_yearly_earnings`

# %% [markdown]
# **Numerical Summary**
#
# Calculate the correlation coefficient to determine the strength and direction of the correlation between video views and average yearly earnings

# %%
# calculate pearson correlation betwen video views and average yearly earnings
youtube_df['video views (millions)'].corr(youtube_df['average_yearly_earnings'])
# Out:
# 0.5846924947490479

# %% [markdown]
# **Visualization**
#
# Create a scatterplot to visualize the relationship between video views and average yearly earnings, highlighting the nature of the correlation.

# %%
# visualize the data
plt.figure(figsize=(16, 8))
sns.scatterplot(x='video views (millions)', y='average_yearly_earnings', data=youtube_df)
plt.xlabel('Video Views')
plt.ylabel('Average Yearly Earnings')
plt.title('Video Views vs. Average Yearly Earnings')
plt.show()

# %% [markdown]
# **Conclusion**
#
# The correlation coefficient only produced a value of 0.58, which means that it only produced a medium positive correlation.

# %% [markdown]
# ### 4. Are there discernible patterns related to a YouTube channel's category and its subscribers?
#
#
# **Description**:
# - We aim to explore if there are discernible patterns related to a YouTube channel's category and its subscribers. We will perform numerical summary and visualization to analyze the data.
#
# **Variables**:
# - `subscribers` : The number of subscribers for YouTube channels.
# - `category` : The category of the YouTube channels.

# %% [markdown]
# **Numerical Summary**
#
# We calculated summary statistics for the `subscribers` column using youtube_df['subscribers'].describe(). The subscribers column represents the `average number of subscribers` for each YouTube channel within their respective categories.

# %%
subscribers_summary = youtube_df['subscribers (millions)'].describe()

# Display the summary statistics
subscribers_summary
# Out:
# count    818.000000
# mean      22.612836
# std       17.260865
# min       12.300000
# 25%       14.500000
# 50%       17.450000
# 75%       24.075000
# max      245.000000
# Name: subscribers (millions), dtype: float64

# %% [markdown]
# **Visualization**
#
# We created a horizontal bar chart to display the average subscribers for each category, using the average_subscribers_by_category variable. The x-axis represents the average subscribers (in millions), and the y-axis displays the categories. The chart is color-coded for better visualization.

# %%
# Bar Chart - Average Subscribers by Category
average_subscribers_by_category = youtube_df.groupby('category')['subscribers (millions)'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=average_subscribers_by_category.values, y=average_subscribers_by_category.index, palette="viridis", orient="h")
plt.title('Average Subscribers by Category')
plt.xlabel('Average Subscribers (in millions)')
plt.ylabel('Category')
plt.show()
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_23896\103581950.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_subscribers_by_category.values, y=average_subscribers_by_category.index, palette="viridis", orient="h")

# %% [markdown]
# **Conclusion**
#
# From our analysis, we have found discernible patterns related to a YouTube channel's category and its subscribers. The analysis revealed the following:
#
# - Shows had the highest average number of subscribers, with an average of over 40 million subscribers.
#
# - Trailers came in second place in terms of average subscribers.
#
# - Movies occupied the third position in terms of average subscribers.
#
# - Autos & Vehicles had the third-to-last position with lower average subscribers.
#
# - Howto & Style ranked second to last in terms of average subscribers.
#
# - Travel & Events was the category with the lowest average number of subscribers.
#
# These patterns suggest that the type of content and category significantly influences the average number of subscribers on YouTube channels. Channels in the "Shows" category, on average, tend to have the most subscribers, while those in the "Travel & Events" category have the fewest. This information can be valuable for content creators and marketers looking to understand subscriber trends on YouTube.

# %% [markdown]
# ### 5. Are there discernible patterns related to a YouTube channel's category and its average yearly earnings?
#
# **Description**:
# - We aim to investigate if there are discernible patterns related to a YouTube channel's category and its average yearly earnings. We will conduct numerical summary and visualization to analyze the data.
#
#
# **Variables**:
# - `category` : The category of the YouTube channels.
# - `lowest_yearly_earnings` : The lowest estimated yearly earnings of the YouTube channels.
# - `highest_yearly_earnings` : The highest estimated yearly earnings of the YouTube channels.

# %% [markdown]
# **Numerical Summary**
#
# We will calculate summary statistics for the 'average_yearly_earnings' column, which is the sum of the lowest and highest yearly earnings. This column represents the average yearly earnings for each YouTube channel within their respective categories.

# %%
# youtube_df['average_yearly_earnings'] = youtube_df['lowest_yearly_earnings'] + youtube_df['highest_yearly_earnings']

youtube_df['average_yearly_earnings'].describe()
# Out:
# count    8.180000e+02
# mean     4.266087e+06
# std      7.607983e+06
# min      5.350000e-01
# 25%      6.900125e+05
# 50%      1.859450e+06
# 75%      4.462800e+06
# max      8.680000e+07
# Name: average_yearly_earnings, dtype: float64

# %% [markdown]
# **Visualization**
#
# We will create a horizontal bar chart to visualize the average yearly earnings for each category, using the average_yearly_earnings_by_category variable. The x-axis will represent the average yearly earnings (in dollars), and the y-axis will display the categories. The chart will be color-coded for better visualization.

# %%
# Bar Chart - Average Yearly Earnings by Category
average_yearly_earnings_by_category = youtube_df.groupby('category')['average_yearly_earnings'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=average_yearly_earnings_by_category.values, y=average_yearly_earnings_by_category.index, palette="viridis", orient="h")
plt.title('Average Yearly Earnings by Category')
plt.xlabel('Average Yearly Earnings (in dollars)')
plt.ylabel('Category')
plt.show()
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_23896\592967771.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_yearly_earnings_by_category.values, y=average_yearly_earnings_by_category.index, palette="viridis", orient="h")

# %% [markdown]
# **Conclusion**
#
# Conclusion:
# From our analysis, we have found discernible patterns related to a YouTube channel's category and its average yearly earnings, calculated as the sum of the lowest and highest yearly earnings. The analysis reveals the following:
#
# - Shows had the highest average yearly earnings, with an average of 1.4 million dollars.
#
# - Pets & Animals came in second place in terms of average yearly earnings.
#
# - Autos & Vehicles occupied the third position in terms of average yearly earnings.
#
# - Science & Technology had the third-to-last position with lower average yearly earnings.
#
# - Howto & Style ranked second to last in terms of average yearly earnings.
#
# - Travel & Events was the category with the lowest average yearly earnings.
#
# These patterns suggest that the category of content significantly influences the average yearly earnings of YouTube channels. Channels in the "Shows" category, on average, tend to have the highest earnings, while those in the "Travel & Evetns" category have the lowest earnings. This information can be valuable for content creators and marketers looking to understand earning trends on YouTube.

# %% [markdown]
# ### 6. What is the distribution of video views for YouTube channels within each content category?
#
# **Description**:
# - We aim to explore the distribution of video views for YouTube channels within each content category.
#
#
# **Variables**:
# - `category` : The category of the YouTube channels.
# - `video views` : The number of video views for each YouTube channel.

# %% [markdown]
# **Numerical Summary**
#
# Calculate the summary statistics for the 'video_views' column within each category. This will help us understand the distribution of video views, including measures like the median, quartiles, and potential outliers for each category.

# %%
# calculate mean of video views within each category 
views_summary = youtube_df.groupby('category')['video views (millions)'].describe()
# views_summary = youtube_df.groupby('category')['video views'].describe()

views_summary
# Out:
#                        count          mean           std           min  \
# category
# Autos & Vehicles         2.0   7501.729071   2964.425984   5405.563355
# Comedy                  58.0   7555.251793   6404.583469   1001.465469
# Education               44.0  15448.128898  25931.842454     20.563378
# Entertainment          212.0  10795.430785  10313.490400    140.022442
# Film & Animation        32.0  12661.945810  12334.406261    902.225615
# Gaming                  83.0   7582.601556   6199.594791    374.123483
# Howto & Style           33.0   3868.477766   2058.999224    264.228052
# Movies                   1.0  10062.770060           NaN  10062.770060
# Music                  175.0  15412.087680  18709.044603    559.765455
# News & Politics         24.0  10635.481307   5142.560034   2255.542592
# Nonprofits & Activism    2.0   5431.455893   2698.145850   3523.578665
# People & Blogs         110.0   9869.009585  13501.817917      0.439098
# Pets & Animals           2.0  14987.375006   7498.604912   9685.060624
# Science & Technology    14.0   3459.242428   1815.592841   1026.425106
# Shows                   12.0  36492.091298  44932.051397   5585.085130
# Sports                  12.0  12928.502219  20773.491324   1948.925559
# Trailers                 1.0  17608.931161           NaN  17608.931161
# Travel & Events          1.0   3140.883140           NaN   3140.883140
#
#                                 25%           50%           75%            max
# category
# Autos & Vehicles        6453.646213   7501.729071   8549.811928    9597.894786
# Comedy                  3281.171939   5351.060414  10078.052476   34300.482066
# Education               3495.474282   7826.723552  15625.610348  164000.000000
# Entertainment           4619.410027   7948.694256  13132.063074   77180.169894
# Film & Animation        5611.928728   8592.232546  13293.304661   59316.472754
# Gaming                  2979.944145   5956.193599   9081.683891   29058.044447
# Howto & Style           2609.358468   3445.794123   4733.873025   10414.479943
# Movies                 10062.770060  10062.770060  10062.770060   10062.770060
# Music                   7231.711651  12140.232004  18856.544268  228000.000000
# News & Politics         7208.523465  10436.259326  14289.575900   25307.753534
# Nonprofits & Activism   4477.517279   5431.455893   6385.394506    7339.333120
# People & Blogs          3695.752107   6159.626652  10256.469141   93247.040539
# Pets & Animals         12336.217815  14987.375006  17638.532198   20289.689389
# Science & Technology    1931.092620   3492.479927   4189.177295    7172.386509
# Shows                  10017.959492  15052.275758  36767.231231  148000.000000
# Sports                  3124.493496   7145.778363  10357.072741   77428.473662
# Trailers               17608.931161  17608.931161  17608.931161   17608.931161
# Travel & Events         3140.883140   3140.883140   3140.883140    3140.883140

# %% [markdown]
# **Visualization**
#
# Create a box plot and bar chart to visually represent the distribution of video views for each category. Box plots are effective for showing the central tendency and spread of data within categories.

# %%
# Horizontal Box Plot - Distribution of Video Views by Category
plt.figure(figsize=(12, 6))
sns.boxplot(x='video views (millions)', y='category', data=youtube_df)
# sns.boxplot(x='video views', y='category', data=youtube_df)
plt.title('Distribution of Video Views by Category')
plt.xlabel('Number of Video Views')
plt.ylabel('Category')
plt.show()

# Horizontal Bar Chart - Distribution of Video Views by Category
plt.figure(figsize=(12, 6))
sns.barplot(x='video views (millions)', y='category', data=youtube_df)
# sns.barplot(x='video views', y='category', data=youtube_df)

plt.title('Distribution of Video Views by Category')
plt.xlabel('Number of Video Views')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# **Conclusion**
#
# Based from our EDA,  in terms of the distribution number of video views per category, the results revealed the following:
# 1. The Shows youtube category has the highest number of video views, out of all other youtube categories.
# 2. The following youtube categories: Trailers, Movies, Travels & Events only have an instance of one YouTube channel, while Nonprofits & Activism, Pets & Animals, and Autos & Vehicles  only have an instance of two YouTube channels. Despite the low number of YouTube Channels in these particular categories, this explains the abnormally small distribution of data within the box plot and the bar chart. Yet still yield a high number of video views.

# %% [markdown]
# ### 7. What are the most prevalent YouTube channel categories in the dataset?
#
# Description:
# - How many channels are in each category?
#
# Variables:
# - `category`
# - `Youtube Channels`

# %% [markdown]
# **Numerical Summary**
#
# Count the frequency of YouTube channels within each unique category.

# %%
category_counts = youtube_df['category'].value_counts()

# Display the count of each unique value
print("Count of each unique value in 'category':")
print(category_counts)
# Out:
# Count of each unique value in 'category':
# category
# Entertainment            212
# Music                    175
# People & Blogs           110
# Gaming                    83
# Comedy                    58
# Education                 44
# Howto & Style             33
# Film & Animation          32
# News & Politics           24
# Science & Technology      14
# Shows                     12
# Sports                    12
# Nonprofits & Activism      2
# Pets & Animals             2
# Autos & Vehicles           2
# Trailers                   1
# Movies                     1
# Travel & Events            1
# Name: count, dtype: int64

# %% [markdown]
# **Visualization**
#
# Create a bar chart to visualize the distribution of YouTube channels across unique categories.

# %%
# create a bar chart to visualize the distribution of YouTube channels across categories
plt.figure(figsize=(12, 6))  # Adjust the figure size
ax = sns.barplot(x=category_counts.values, y=category_counts.index, palette="viridis", orient="h")
ax.set(xlabel='Number of Channels', ylabel='Category')
plt.title('Distribution of YouTube Channels Across Categories')

# Add data labels to the right of each bar for readability
for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{int(width)}', xy=(width, p.get_y() + p.get_height() / 2), ha='left', va='center', fontsize=9, color='black')

plt.tight_layout()  # Ensure labels and titles fit in the plot area
plt.show()
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_23896\910500672.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.values, y=category_counts.index, palette="viridis", orient="h")

# %% [markdown]
# **Conclusion**
#
# Notably, the Entertainment category stands out as the most prominent, encompassing approximately 20% of the channels, totaling around 212 channels. Following closely is the Music category, with 175 channels falling under this classification. The next three top categories include People & Blogs, Gaming, and Comedy. It's interesting to note that despite the Pets and Animals category being among the highest earners, it is represented by only 2 channels in our dataset, underscoring the niche nature of this content within the YouTube landscape.

# %% [markdown]
# ### 8. What is the distribution of YouTube channels by their country of origin in the dataset? Retrieve the top 15 countries.
#
# Description:
# - aims to identify the top 15 countries with most amount of channels.
#
# Variables:
# - `Country`
# - `Youtube Channels`

# %% [markdown]
# **Numerical Summary**
#
# Get the frequency of YouTube channels from each country.
#
# Retrieve the top 15 countries with most frequency of YouTube channels.

# %% [markdown]
# country_counts = youtube_df['Country'].value_counts()

# %%
top_15_countries = country_counts[:15]

top_15_countries
# Out:
# Country
# United States     306
# India             167
# Brazil             61
# United Kingdom     43
# Mexico             30
# Indonesia          28
# Spain              22
# Thailand           18
# South Korea        17
# Russia             15
# Canada             14
# Argentina          13
# Philippines        12
# Colombia           11
# Ukraine             8
# Name: count, dtype: int64

# %% [markdown]
# **Visualization**
#
# Create a bar chart to visualize the distribution of YouTube channels by country – showing only the top 15.

# %%
plt.figure(figsize=(12, 6))  # Adjust the figure size
ax = sns.barplot(x=top_15_countries.values, y=top_15_countries.index, palette="viridis", orient="h")
ax.set(xlabel='Number of Channels', ylabel='Country')
plt.title('Distribution of YouTube Channels Across Countries')

# Add data labels to the right of each bar for readability
for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{int(width)}', xy=(width, p.get_y() + p.get_height() / 2), ha='left', va='center', fontsize=9, color='black')

plt.tight_layout()  # Ensure labels and titles fit in the plot area
plt.show()
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_23896\4159285927.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_15_countries.values, y=top_15_countries.index, palette="viridis", orient="h")

# %% [markdown]
# **Conclusion**
#
# The distribution of channels in our exploratory data analysis reveals a clear dominance by the United States and India, with the United States leading with 306 channels and India following closely with approximately 167 channels. Beyond these two leaders, the distribution becomes less pronounced, with countries like Brazil, the United Kingdom, Mexico, and others falling within a range of approximately 65 channels, showing a less significant presence in this context.

# %% [markdown]
# # Research Question
#     This section of the Jupyter Notebook contains this study's Research Question that we wish to answer based from our results and findings from the Exploratory Data Ananlysis.

# %% [markdown]
#     After careful consideration of our observations and analysis, we want to answer the following research question.
# ### What are the key factors that makes a YouTube Channel Successfull?
#
# #### In connection with the EDA's...
# Based on our exploratory data analysis, it is evident that determining the success of a YouTube channel is a wide ranging task; it is not solely reliant on one variable. Our findings reveal that a channel can excel in certain metrics while falling short in others. A noteworthy case in point is the earnings of successful YouTube channels, where some channels with high view and subscriber counts may generate minimal or no revenue due to certain reasons, and conversely, some less prominent channels might generate substantial earnings. with that said, there are some metrics that do have some sort of correlation with each other. The positive correlation between subscriber count and view count for a YouTube channel means that having a higher subscriber count means having a higher view count.
#
# Our data analysis suggests that there are potential factors that have a positive correlation with the metrics that determine the success of a YouTube channel. These factors include a channel’s category of content and country origin. However, further study is needed to specifically find the correlation of a potential factor to each given metric of success.
#
#
# #### Description:
#
# - Analyzing the observations from our exploratory data analysis, we have observed that there are existing key factors that explains the high values in some the YouTube Metrics
# - A YouTube Channel’s success can be derived from these existing factors which explains why a given YouTube Channel’s Analytics considers metrics such as impressions, click-through, likes, shares, view count, subscriber, and the list goes on. Youtube Channel Analytics is a bird’s eye view to monitor its channel vitals, like real-time views, total views, watch time, subscribers, etc. It is perfect for getting a performance overview over a period at a quick glance.
# - In consideration of YouTube's Algorithm, it also looks at the demography of viewer's video relevance and category and recommends it to similar audiences.
# - In addition, considering a success metric that will determine “success” for a youtube video, this would include subscribers, video views, earnings, rankings(overall and country). We test out other parameters in the dataset that we can consider “factors”, this could be country, population count of the country, category.
#
# ### Significance of the Study
#
#     In determining the factors that enhances a YouTube Channel’s success, it carries substantial importance on various fronts. It provides practical guidance for content creators, empowering them to make data-driven choices about their content and strategies. This research has broader industry implications as it aids businesses in optimizing their marketing endeavors on the YouTube platform. Moreover, unraveling these success factors contributes to the academic understanding of digital media, informs evidence-based decision-making, and can potentially influence policies and regulations pertaining to online content. This study could extend its impact to a wider spectrum, offering insights into the dynamics of content creation and user engagement in the digital realm, making it a multidimensional and highly pertinent field of inquiry.

# %% [markdown]
# # Phase 2
#
#
#         In the second phase of the case study, which encompasses data modeling, statistical inference, and drawing insights and conclusions, a systematic approach was adopted to address the research question at hand.

# %% [markdown]
# ## Dependent and Independent Variable
#     In this notebook, our selected dataset and based from our research question, yields us the following variables...
#
# ### Dependent Variable
# - **`subscribers (millions)`**: Number of subscribers to the channel (Rank of the YouTube channel is based on the number of subscribers)
#
# - **`video views (millions)`**: Overall count views to the channel
#
# - **`earnings`**: Total earnings of the youtuber
#     - **`Monthly Earnings`**:
#         - **`lowest_monthly_earnings`**: Lowest estimated monthly earnings from the channel in Dollars
#         - **`highest_monthly_earnings`**: Highest estimated monthly earnings from the channel in Dollars
#     - **`Yearly Earnings`**:
#         - **`lowest_yearly_earnings`**: Lowest estimated yearly earnings from the channel in Dollars
#         - **`highest_yearly_earnings`**: Highest estimated yearly earnings from the channel in Dollars
#
# ### Independent Variables
# - **`Youtuber`**: Name of the YouTube channel
# - **`category`**: Category or niche of the channel
# - **`uploads`**: Total number of videos uploaded on the channel
# - **`Country`**: Country where the YouTube channel originates
# - **`video_views_for_the_last_30_days`**: Total video views in the last 30 days
# - **`Population (millions)`**: Total population of the country
# - **`created_year`**: Year when the YouTube channel was created

# %% [markdown]
# ## Data Modelling
#
# ### Objective
# In addressing the research question related to channel success on the platform, several data modeling steps were undertaken to gain meaningful insights. The initial phase involved preprocessing techniques to ensure the data was in an appropriate representation for subsequent modeling. This encompassed transformations such as feature scaling and outlier detection, tailored to enhance the suitability of the data for the chosen modeling techniques. Normalization was applied to certain variables, considering the requirements of specific algorithms used in the subsequent analysis. Consequently, careful attention was paid to scaling the data appropriately, ensuring that the modeling techniques utilized could operate optimally and yield accurate results.
#
# The choice of data modeling techniques adhered to those discussed in class, ensuring alignment with the covered material. For instance, linear regression models were employed to investigate the relationships between key variables, such as subscribers, video views, and earnings. These models facilitated the exploration of linear associations and provided insights into the impact of population size, creation date, and other relevant factors on the main metrics.

# %% [markdown]
# ### Data Preprocessing
#
# In this project, the user performed data preprocessing to prepare the data for analysis. Specifically, outlier detection and removal were performed on several columns including:
#  - **`subscribers (millions)`**
#  - **`uploads`**
#  - **`Population (millions)`**
#  - **`created_year`**
#  - **`video views (millions)`**
#  - **`average_yearly_earnings`**
#
# A z-score threshold of 3 standard deviations from the mean was employed during outlier detection and removal in the data preprocessing phase. This specific threshold was chosen for several reasons:
#  - A threshold of 3 standard deviations helps ensure that only data points significantly deviating from the mean are flagged as outliers.
#  - It allows for the removal of extreme values while retaining a sufficient amount of data for a meaningful analysis.
#  - By removing outliers using a z-score threshold of 3, the subsequent normalization process is less likely to be skewed by these extreme values, leading to a more accurate representation of the data distribution.
#
#  This was done to ensure the accuracy of the data and to address any potential skewness or bias in the data. This was a necessary process since we plan on using normalization on the data. Normalization tends to be susceptible to outliers hence their removal.

# %%
# First, we will get the average monthly and yearly earnings that will be used for the following hypotheses

# Add the Average Earnings columns to the list of columns to scale
youtube_df['average_yearly_earnings'] = (youtube_df['lowest_yearly_earnings'] + youtube_df['highest_yearly_earnings']) / 2

column_names = ['subscribers (millions)', 'uploads', 'Population (millions)', 'created_year', 'video views (millions)', 'average_yearly_earnings']
z_score_threshold = 3
filtered_df = youtube_df.copy()

for column_name in column_names:
    column_data = filtered_df[column_name]
    filtered_df = filtered_df[(np.abs(stats.zscore(column_data)) < z_score_threshold)]

youtube_df = filtered_df

youtube_df
# Out:
#                      Youtuber  subscribers (millions)  video views (millions)  \
# 13              Justin Bieber                    71.6            30608.119724
# 14                HYBE LABELS                    71.3            28634.566938
# 18       Shemaroo Filmi Gaane                    65.6            28648.024439
# 20               Dude Perfect                    59.5            16241.549158
# 22              Tips Official                    59.3            33431.802698
# ..                        ...                     ...                     ...
# 815             Natan por A__                    12.3             9029.609749
# 816  Free Fire India Official                    12.3             1674.409945
# 817                     Panda                    12.3             2214.684303
# 818               RobTopGames                    12.3              374.123483
# 819              Make Joke Of                    12.3             2129.773714
#
#            category  uploads         Country  lowest_monthly_earnings  \
# 13            Music    249.0          Canada                  44100.0
# 14            Music   1337.0     South Korea                 149500.0
# 18            Music   8502.0           India                  63700.0
# 20           Sports    389.0   United States                  35300.0
# 22            Music   4741.0           India                 105700.0
# ..              ...      ...             ...                      ...
# 815          Sports   1200.0          Brazil                 138100.0
# 816  People & Blogs   1500.0           India                  16200.0
# 817          Gaming   2452.0  United Kingdom                     17.0
# 818          Gaming     39.0          Sweden                    968.0
# 819          Comedy     62.0           India                   6000.0
#
#      highest_monthly_earnings  lowest_yearly_earnings  \
# 13                   705300.0                529000.0
# 14                  2400000.0               1800000.0
# 18                  1000000.0                764900.0
# 20                   564800.0                423600.0
# 22                  1700000.0               1300000.0
# ..                        ...                     ...
# 815                 2200000.0               1700000.0
# 816                  258900.0                194200.0
# 817                     268.0                   201.0
# 818                   15500.0                 11600.0
# 819                   96000.0                 72000.0
#
#      highest_yearly_earnings  created_year  Population (millions)  \
# 13                 8500000.0        2007.0                 36.992
# 14                28700000.0        2008.0                 51.709
# 18                12200000.0        2010.0               1366.418
# 20                 6800000.0        2009.0                328.240
# 22                20300000.0        2007.0               1366.418
# ..                       ...           ...                    ...
# 815               26500000.0        2017.0                212.559
# 816                3100000.0        2018.0               1366.418
# 817                   3200.0        2006.0                 66.834
# 818                 185800.0        2012.0                 10.285
# 819                1200000.0        2017.0               1366.418
#
#      average_yearly_earnings
# 13                 4514500.0
# 14                15250000.0
# 18                 6482450.0
# 20                 3611800.0
# 22                10800000.0
# ..                       ...
# 815               14100000.0
# 816                1647100.0
# 817                   1700.5
# 818                  98700.0
# 819                 636000.0
#
# [755 rows x 13 columns]

# %% [markdown]
# Additionally, normalization was performed on the said data to address any potential issues with scale and distribution. This was performed on several columns including:
#  - **`subscribers (millions)`**
#  - **`uploads`**
#  - **`Population (millions)`**
#  - **`created_year`**
#  - **`video views (millions)`**
#  - **`average_yearly_earnings`**
#
# This crucial step was taken to standardize the scale and distribution of the data, ensuring a fair comparison across variables. Normalization is particularly important when employing t-tests to assess hypotheses.
#
# Normalization aids in creating a level playing field for variables with different units and ranges, allowing the subsequent t-tests to provide meaningful results. By transforming the data to a common scale, the impact of varying magnitudes among the features is minimized, preventing any single variable from disproportionately influencing the outcomes of the statistical tests.
#
# The t-tests, in turn, rely on the assumption that the data is approximately normally distributed. Normalization contributes to meeting this assumption, enhancing the reliability of the t-test results. The calculated scores and p-values from the t-tests are crucial in evaluating whether to accept or reject the null and alternative hypotheses, providing valuable insights into the significance of observed differences or relationships within the data.

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
column_names = ['subscribers (millions)', 'uploads', 'Population (millions)', 'created_year', 'video views (millions)', 'average_yearly_earnings']

# Create a new DataFrame with only the selected columns
selected_columns_df = youtube_df[column_names]

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Perform normalization on the selected columns
normalized_data = scaler.fit_transform(selected_columns_df)

# Create a new DataFrame with the normalized data
normalized_df = pd.DataFrame(normalized_data, columns=column_names)

# %% [markdown]
# ### Models in relation to Subscriber Count

# %%
# Create a scatter plot
plt.scatter(youtube_df['subscribers (millions)'], youtube_df['video views (millions)'])

# Add labels and title
plt.xlabel('Subscribers (millions)')
plt.ylabel('Video Views (millions)')
plt.title('Scatter Plot of Subscribers vs Video Views')

# Display the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(youtube_df['subscribers (millions)'], youtube_df['uploads'])

# Add labels and title
plt.xlabel('Subscribers (millions)')
plt.ylabel('Uploads')
plt.title('Scatter Plot of Subscribers vs Uploads')

# Display the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(youtube_df['subscribers (millions)'], youtube_df['average_yearly_earnings'])

# Add labels and title
plt.xlabel('Subscribers (millions)')
plt.ylabel('Average Yearly Earnings')
plt.title('Scatter Plot of Subscribers vs Average Yearly Earnings')

# Display the plot
plt.show()

# %%
subscriber_count = youtube_df.groupby('category')['subscribers (millions)'].sum()
subscriber_count.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Category')
plt.ylabel('Subscriber Count (millions)')
plt.title('Subscriber Count by Category')
plt.show()

# %% [markdown]
# ### Models in Relation to Video Views

# %%
# Create the scatter plot
plt.scatter(youtube_df['video views (millions)'], youtube_df['average_yearly_earnings'])

# Add labels and title
plt.xlabel('Video Views (millions)')
plt.ylabel('Average Yearly Earnings')
plt.title('Scatter Plot of Video Views vs Average Yearly Earnings')

# Display the plot
plt.show()

# %%
# Create the scatter plot
plt.scatter(youtube_df['video views (millions)'], youtube_df['uploads'])

# Add labels and title
plt.xlabel('Video Views (millions)')
plt.ylabel('Uploads')
plt.title('Scatter Plot of Video Views vs Uploads')

# Display the plot
plt.show()

# %%
youtube_df.groupby('category')['video views (millions)'].sum().plot(kind='bar', figsize=(10, 6))
plt.xlabel('Category')
plt.ylabel('Video Views (millions)')
plt.title('Video Views by Category')
plt.show()

# %%
youtube_df.groupby('Country')['video views (millions)'].sum().plot(kind='bar', figsize=(10, 6))
plt.xlabel('Country')
plt.ylabel('Video Views (millions)')
plt.title('Video Views by Country')
plt.show()

# %% [markdown]
# ### Models in Relation to Average Yearly Earnings

# %%
# Create the scatter plot
plt.scatter(youtube_df['Population (millions)'], youtube_df['average_yearly_earnings'])

# Add labels and title
plt.xlabel('Population (millions)')
plt.ylabel('Average Yearly Earnings')
plt.title('Scatter Plot of Average Yearly Earnings vs Population')

# Display the plot
plt.show()

# %%
# Create the scatter plot
plt.scatter(youtube_df['average_yearly_earnings'], youtube_df['uploads'])

# Add labels and title
plt.xlabel('Uploads')
plt.ylabel('Average Yearly Earnings')
plt.title('Scatter Plot of Uploads vs Average Yearly Earnings')

# Display the plot
plt.show()

# %%
subscriber_count = youtube_df.groupby('Country')['average_yearly_earnings'].sum()
subscriber_count.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Country')
plt.ylabel('Average Yearly Earnings')
plt.title('Average Yearly Earnings by Country')
plt.show()

# %%
subscriber_count = youtube_df.groupby('category')['average_yearly_earnings'].sum()
subscriber_count.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Category')
plt.ylabel('Average Yearly Earnings')
plt.title('Average Yearly Earnings by Category')
plt.show()

# %%
# Plotting the histogram
plt.hist(youtube_df['subscribers (millions)'], bins=15, edgecolor='black')

# Adding labels and title
plt.xlabel('Subscriber Count (millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Subscriber Count')

# Displaying the histogram
plt.show()

# %% [markdown]
# ### Histograms

# %%
# Plotting the histogram
plt.hist(youtube_df['video views (millions)'], bins=15, edgecolor='black')

# Adding labels and title
plt.xlabel('Video Views (millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Video Views')

# Displaying the histogram
plt.show()

# %%
# Plotting the histogram
plt.hist(youtube_df['average_yearly_earnings'], bins=15, edgecolor='black')

# Adding labels and title
plt.xlabel('Average Yearly Earnings (millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Average Yearly Earnings')

# Displaying the histogram
plt.show()

# %% [markdown]
# ## Statistical Inference
#
# In the statistical inference section of our study, we delve into the heart of our data analysis, seeking to draw meaningful conclusions and insights from the structured YouTube dataset. Through a rigorous application of statistical techniques and methodologies, we aim to extract valuable information about the platform's performance, trends, and user behaviors. Statistical inference allows us to identify patterns, correlations, and dependencies within the data, offering answers to critical questions about user engagement, content preferences, and the impact of various factors on YouTube's success.
#
# By conducting hypothesis tests, regression analyses, and other statistical procedures, we can make informed assessments of the relationships between different variables. Moreover, we explore the significance of various factors, such as video length, publication time, and audience demographics, in influencing viewership and engagement. This section of our study enables us to provide evidence-based insights into the factors contributing to the dynamics of YouTube's global ecosystem, helping content creators, businesses, and researchers better understand how to navigate and succeed in the ever-evolving world of online video content.

# %% [markdown]
# ## Hypothesis 1
#
# In this section of the notebook, the group aims to conduct a statistical analysis to investigate potential associations or dependencies between certain variables within the dataset with a Youtuber’s Subscriber Count. The goal is to assess whether specific factors exhibit a statistically significant relationship with the ranking.

# %% [markdown]
# ### Hypothesis 1.1:  Is Subscriber Count associated/dependent with the channel’s country of origin?
#     In determining whether a Youtuber's Subscriber Count is associated with the channel's country of origin, the group utilizes a chi-square test with a significance level, the investigation assesses if there is a dependency between these variables. By exploring the relationship, the study examines how geographic elements, such as cultural preferences and regional trends, may influence the Subscriber Count. The focus is on detecting meaningful associations or dependencies between the two variables.
#
# **`Null Hypothesis:`** There is no association or dependency between the rank of channels and their country of origin. Mathematically
#
# **`Alternative Hypothesis:`** There is a significant association or dependency between the rank of channels and their country of origin.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Canada'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'South Korea'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'United States'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'India'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'United Kingdom'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Chile'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Russia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Cuba'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'El Salvador'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Mexico'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Barbados'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Colombia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Thailand'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Brazil'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Spain'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Argentina'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Saudi Arabia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'United Arab Emirates'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Indonesia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Philippines'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Venezuela'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Kuwait'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Jordan'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Netherlands'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Pakistan'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Australia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Japan'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Germany'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'France'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Sweden'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Ukraine'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Turkey'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Switzerland'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Vietnam'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Malaysia'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'China'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Iraq'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Singapore'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Egypt'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Ecuador'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Morocco'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Peru'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Finland'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Samoa'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Italy'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Germany'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'France'],
                    youtube_df['subscribers (millions)'][youtube_df['Country'] == 'Sweden'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 1.111317086644828
# p-value: 0.2860250414362083

# %% [markdown]
# #### Findings and Results for Hypothesis 1.1
#
#    Based on the results and findings of the ANOVA test investigating the association between a Youtuber's Subscriber Count and the channel's country of origin, it yielded a F-statistic value of **`1.1113`**, which is quite small. This suggests that the variance between the groups (i.e., the differences in 'subscribers (millions)' between different countries) is not significantly larger than the variance within the groups (i.e., the differences in 'subscribers (millions)' within each country). The associated p-value, calculated as **`0.2860`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is greater than the significance level.
#
#    In summary, these findings indicate that **`there is not enough evidence to conclude that there is a significant difference in 'subscribers (millions)' between the different countries.`** Therefore we **`accept`** the null hypothesis.

# %% [markdown]
# ### Hypothesis 1.2:  Is rank associated/dependent with the channel’s upload count?
#     In determining whether there exists a statistically significant relationship between the rank of YouTube channels and their upload count. Upload count serves as a proxy for the frequency and consistency of content production, which could influence viewer engagement and, consequently, a channel's rank The group's focus is to investigate whether the frequency of content uploads has a discernible association or dependency on a channel's ranking . This exploration is essential for understanding the potential association between a channel's upload activity and its perceived popularity or success.
#
# **`Null Hypothesis:`** There is no association or dependency between the rank of Youtube Channels and the channel's upload count
#
# **`Alternative Hypothesis:`** There is a significant association or dependency between the rank of channels and their country of origin.

# %%
data = {'subscribers': normalized_df['subscribers (millions)'],
        'uploads': normalized_df['uploads']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['subscribers'], df['uploads'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = 13.654293860843083
# p-value = 4.154566255687229e-40

# %% [markdown]
# #### Findings and Results for Hypothesis 1.2
#
#    Based on the results and findings of the t-test investigating the association between a Youtuber's Subscriber Count and uploads, it yielded a t-statistic value of **`13.6543`**. This suggests that the mean difference between the groups (i.e., the differences in 'subscriber (millions)' and 'uploads') is significantly larger than the variance within the groups.
#
#    The associated p-value, calculated as  **`4.1546e-40`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
#    In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'subscriber (millions)' and 'uploads'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'Subscriber Count' and 'Upload Count' variables do significantly explain the variation in 'subscriber (millions)' and 'uploads'.

# %% [markdown]
# ### Hypothesis 1.3:  Is Subscriber Count associated/dependent with the channel’s category?
#     In investigating the existence of an association or dependence between a Youtuber's Subscriber Count and the category of their channel. THe group's aim is to discern whether the content genre, represented by the channel's category, significantly influences the number of subscribers it attracts. This exploration is crucial for understanding the connection between a channel's content type and its perceived popularity, as measured by the Subscriber Count. It suggests that the channel's category plays a pivotal role in shaping its Subscriber Count. Diverse content genres attract varied audiences, and by examining the association between Subscriber Count and channel category, the analysis seeks to unveil whether specific categories tend to attract higher subscriber numbers. This understanding provides valuable insights for content creators aiming to optimize their channel's category for enhanced subscriber engagement and overall success on the platform.
#
# In summary, these results affirm that content category plays a crucial role in determining a Youtuber's popularity, as reflected by their Subscriber Count. Therefore, we [reject/do not reject] the null hypothesis, based on the p-value and the chosen significance level.
#
# **`Null Hypothesis:`** There is no association or dependence between the Subscriber Count and the channel's category.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the Subscriber Count and the channel's category.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['subscribers (millions)'][youtube_df['category'] == 'Music'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Sports'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Entertainment'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Film & Animation'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Education'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Gaming'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Comedy'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'People & Blogs'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Shows'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Trailers'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Howto & Style'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Science & Technology'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Movies'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'News & Politics'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Pets & Animals'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Autos & Vehicles'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Nonprofits & Activism'],
                    youtube_df['subscribers (millions)'][youtube_df['category'] == 'Travel & Events'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 2.1235189206200307
# p-value: 0.005184338234579133

# %% [markdown]
# #### Findings and Results for Hypothesis 1.3
# Based on the results and findings of the ANOVA test investigating the association between a Youtuber's Subscriber Count and the channel's category, it yielded a F-statistic value of **`2.1235`**. This suggests that the variance between the groups (i.e., the differences in 'subscribers (millions)' between different categories) is significantly larger than the variance within the groups (i.e., the differences in 'subscribers (millions)' within each category).
#
# The associated p-value, calculated as **`0.005184`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'subscribers (millions)' between the different categories.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'category' variable does significantly explain the variation in 'subscribers (millions)'.

# %% [markdown]
# ### Hypothesis 1.4:  Is Subscriber Count associated or dependent with the population of the country of origin?
#     In exploring the existence of association or dependency between a Youtuber's Subscriber Count and the population of their country of origin. The obbective is mainly to investigate whether the demographic size of a country has a statistically significant impact on the number of subscribers a Youtuber attracts, aiming to uncover any association or dependency between Subscriber Count and the population of the country of origin. Population of a Youtuber's country of origin plays a substantial role in shaping their Subscriber Count. A larger population might suggest a broader potential audience, while a smaller population could imply a more niche viewership. By scrutinizing the association between Subscriber Count and the population of the country of origin, the analysis seeks to reveal whether Youtubers from countries with larger populations tend to have higher subscriber numbers. Understanding this potential association provides valuable insights into the broader demographic factors that may contribute to a Youtuber's popularity.
#
# **`Null Hypothesis:`** There is no association or dependence between the Subscriber Count and the population of the country of origin.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the Subscriber Count and the population of the country of origin.

# %%
data = {'subscribers': normalized_df['subscribers (millions)'],
        'population': normalized_df['Population (millions)']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['subscribers'], df['population'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -12.536342594444692
# p-value = 2.2873887693128236e-34

# %% [markdown]
# #### Findings and Results for Hypothesis 1.4
#
#    Based on the results and findings of the t-test investigating the association between a Youtuber's Subscriber Count and the population, it yielded a t-statistic value of **`-12.5363`**. This suggests that the mean difference between the groups (i.e., the differences in 'subscribers (millions)' and 'Population (million)') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`2.2874e-34`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'subscribers (millions)' and 'Population (million)'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'subscribers (millions)' and 'Population (million)' variables do significantly explain the variation in 'subscribers (millions)' and 'Population (million)'.

# %% [markdown]
# ### Hypothesis 1.5:  Is Subscriber Count associated/dependent with the channel’s creation date?
#     In exploring the potential connection between a Youtuber's Subscriber Count and the channel's creation date. The main goal is to determine if the age of a channel, represented by its creation date, has a significant association the number of subscribers it attracts. The hypothesis posits that the creation date of a YouTube channel carries meaningful implications for its Subscriber Count, reflecting factors such as platform tenure, visibility, reputation, and subscriber acquisition trends over time. Seeking to uncover whether older channels generally boast higher subscriber numbers or if newer channels can also achieve notable subscriber engagement.
#
# **`Null Hypothesis:`** There is no association or dependence between the Subscriber Count and the channel's creation date.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the Subscriber Count and the channel's creation date.

# %%
data = {'subscribers': normalized_df['subscribers (millions)'],
        'created_year': normalized_df['created_year']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['subscribers'], df['created_year'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -30.40899412345079
# p-value = 8.416885833245343e-159

# %% [markdown]
# #### Findings and Results for Hypothesis 1.5
#    Based on the results and findings of the t-test investigating the association between a Youtuber's Subscriber Count and the year the channel was created, it yielded a t-statistic value of **`-30.4090`**. This suggests that the mean difference between the groups (i.e., the differences in 'subscriber (millions)' between different years) is significantly larger than the variance within the groups (i.e., the differences in 'subscriber (millions)' within each year).
#
# The associated p-value, calculated as **`8.4169`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'subscriber (millions)' between the different years.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'created_year' variable does significantly explain the variation in 'subscriber (millions)'.

# %% [markdown]
# ### Hypothesis 1.6:  Is Subscriber Count associated/dependent with the channel’s video views?
#
#     In examining the associative relationship between a Youtuber's Subscriber Count and the channel's video views. The hypothesis posits a significant association, investigating whether a channel's popularity, reflected in Subscriber Count, is linked to the overall engagement seen in video views. The analysis aims to reveal whether channels with higher Subscriber Counts also tend to accumulate more video views.
#
# **`Null Hypothesis:`** There is no association or dependence between the Subscriber Count and the channel's video views.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the Subscriber Count and the channel's video views.

# %%
data = {'subscribers': normalized_df['subscribers (millions)'],
        'video views': normalized_df['video views (millions)']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['subscribers'], df['video views'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -13.724056884566167
# p-value = 1.7687749295833491e-40

# %% [markdown]
# #### Findings and Results for Hypothesis 1.6
#
#    Based on the results and findings of the t-test investigating the association between a Youtuber's Subscriber Count and Video Views, it yielded a t-statistic value of **`-13.6241`**. This suggests that the mean difference between the groups (i.e., the differences in 'subscribers (millions)' and 'video views (millions)') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`1.7688e-40`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'subscriber (millions)' and 'video views (millions)'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'subscribers (millions)' and 'video views (millions)' variables do significantly explain the variation in 'subscribers (millions)' and 'video views (millions)'.

# %% [markdown]
# ### Hypothesis 1.7:  Is subscriber count associated/dependent with the channel’s yearly earnings?
#     In exploring the potential relationship between a Youtuber's Subscriber Count and the channel's yearly earnings. Our aim is to assess whether the financial success of a channel, represented by its average yearly earnings, has a statistically significant association with its Subscriber Count. A significant association or dependence between a Youtuber's Subscriber Count and the channel's average yearly earnings. The inquiry focuses on understanding whether a channel's popularity, reflected in Subscriber Count, aligns with its financial success measured by yearly earnings. This analysis aims to uncover whether channels with higher Subscriber Counts tend to generate greater yearly earnings and vice versa.
#
# **`Null Hypothesis:`** There is no association or dependence between the Subscriber Count and the channel's average yearly earnings.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the Subscriber Count and the channel's average yearly earnings

# %%
data = {'subscribers': normalized_df['subscribers (millions)'],
        'average_yearly_earnings': normalized_df['average_yearly_earnings'],}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['subscribers'], df['average_yearly_earnings'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = 0.5870074998024208
# p-value = 0.5572865387796999

# %% [markdown]
# #### Findings and Results for Hypothesis 1.7
# Based on the results and findings of the t-test investigating the association between a Youtuber's Subscriber Count and the average yearly earnings, it yielded a t-statistic value of **`0.5870`**. This suggests that the mean difference between the groups (i.e., the differences in 'subscribers (millions)' and 'average_yearly_earnings') is not significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`0.5573`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is greater than the significance level.
#
# In summary, these findings indicate that **`there is not enough evidence to conclude that there is a significant difference in 'subscribers (millions)' and 'average_yearly_earnings'.`** Therefore we **`accept`** the null hypothesis. This suggests that the 'subscribers (millions)' and 'average_yearly_earnings' variables do not significantly explain the variation in 'subscribers (millions)' and 'average_yearly_earnings'.

# %% [markdown]
# ## Hypothesis 2
#
#     In this section, we intend to perform a statistical analysis to assess potential associations or dependencies between various variables within the dataset with the Youtuber's total number of video views. The objective is to determine whether specific factors demonstrate a statistically significant relationship with the total count of video views for a Youtuber.

# %% [markdown]
# ### Hypothesis 2.1:  Is a Youtube Channel’s video views associated or dependent with the channel’s country of origin?
#     In innvestigating the potential associations or dependencies between a Youtuber's total number of video views and the country of origin of their channel, our  objective is to determine whether the geographic location of the channel has a statistically significant relationship with the overall count of video views. By examining the association between video views and the country of origin, the analysis seeks to identify whether specific countries are more likely to yield higher video views for a Youtuber. This exploration provides valuable insights into the geographical factors that shape a channel's video viewership.
#
# **`Null Hypothesis:`** There is no association or dependence between the 'Video Views' and the Country origin of the YouTube channel.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between the 'Video Views' and the Country origin of the YouTube channel.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['video views (millions)'][youtube_df['Country'] == 'Canada'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'South Korea'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'United States'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'India'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'United Kingdom'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Chile'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Russia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Cuba'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'El Salvador'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Mexico'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Barbados'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Colombia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Thailand'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Brazil'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Spain'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Argentina'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Saudi Arabia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'United Arab Emirates'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Indonesia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Philippines'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Venezuela'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Kuwait'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Jordan'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Netherlands'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Pakistan'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Australia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Japan'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Germany'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'France'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Sweden'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Ukraine'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Turkey'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Switzerland'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Vietnam'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Malaysia'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'China'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Iraq'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Singapore'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Egypt'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Ecuador'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Morocco'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Peru'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Finland'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Samoa'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Italy'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Germany'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'France'],
                    youtube_df['video views (millions)'][youtube_df['Country'] == 'Sweden'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 1.568313469381224
# p-value: 0.010211999337615367

# %% [markdown]
# #### Findings and Results for Hypothesis 2.1
# Based on the results and findings of the ANOVA test investigating the association between a Youtuber's video views and the channel's country, it yielded a F-statistic value of **`1.5683`**. This suggests that the variance between the groups (i.e., the differences in 'video views (millions)' between different countries) is significantly larger than the variance within the groups (i.e., the differences in 'video views (millions)' within each country).
#
# The associated p-value, calculated as **`0.010212`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'video views (millions)' between the different countries.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'Country' variable does significantly explain the variation in 'video views (millions)'.

# %% [markdown]
# ### Hypothesis 2.2: Is a channel’s video views associated/dependent with the channel’s upload count?
#     In exploring the potential relationship between a Youtuber's total number of video views and the upload count of their channel, our objective was is to investigate whether the frequency of content uploads, as indicated by the upload count, has a statistically significant association with the overall count of video views. the upload count of a YouTube channel significantly influences its total number of video views, with the frequency and consistency of content uploads playing a crucial role in impacting viewer engagement and contributing to the overall video viewership. By scrutinizing the association between video views and the upload count, we seek to determine whether channels with a higher upload count tend to attract more video views, providing valuable insights into the impact of content production frequency on a channel's overall video viewership.
#
# **`Null Hypothesis:`** There is no association between the 'upload count' and the ‘video views’ of the YouTube channel.
#
# **`Alternative Hypothesis:`** There is a significant relationship between the upload count of a channel and its video views.

# %%
data = {'video views': normalized_df['video views (millions)'],
        'uploads': normalized_df['uploads']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['uploads'], df['video views'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -26.59357535684906
# p-value = 4.2711289709943327e-128

# %% [markdown]
# #### Findings and Results for Hypothesis 2.2
# Based on the results and findings of the t-test investigating the association between a Youtuber's video views and the number of uploads, it yielded a t-statistic value of **`-26.5936`**. This suggests that the mean difference between the groups (i.e., the differences in 'video views (millions)' and 'uploads') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`4.2711e-128`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant relationship between 'video views' and 'uploads'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'video views (millions)' and 'uploads' variables do significantly explain the variation in 'video views (millions)' and 'uploads'.

# %% [markdown]
# ### Hypothesis 2.3:  Is a channel’s video views associated/dependent with the population of the country of origin?
#     In investigating the potential relationship between a Youtuber's total number of video views and the population of their country of origin. Our objective is to examine whether the demographic size of a country has a statistically significant association with the total count of video views. This exploration aims to uncover whether there is a meaningful dependency between a channel's video viewership and the population of its country of origin. A population of a Youtuber's country of origin may play a significant role in influencing their total number of video views. The demographic size of a country can impact the potential audience base and viewer engagement. By scrutinizing the association between video views and the population of the country of origin, we reveal whether Youtubers from countries with larger populations tend to have higher video views. Understanding this potential association provides valuable insights into the broader demographic factors that may contribute to a Youtuber's overall video viewership.
#
# **`Null Hypothesis:`** There is no association between video views and the population of the country of origin.
#
# **`Alternative Hypothesis:`** There is a significant relationship between video views and the population of the country of origin.

# %%
data = {'video views': normalized_df['video views (millions)'],
        'population': normalized_df['Population (millions)']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['video views'], df['population'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -3.141120049727053
# p-value = 0.0017157275685817472

# %% [markdown]
# #### Findings and Results for Hypothesis 2.3.
# Based on the results and findings of the t-test investigating the association between a Youtuber's video views and the population, it yielded a t-statistic value of **`-3.141`**. This suggests that the mean difference between the groups (i.e., the differences in 'video views (millions)' and 'Population (millions)') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`0.0017`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant relationship in 'video views (millions)' and 'population'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'video views (millions)' and 'Population (millions)' variables do significantly explain the variation in 'video views (millions)' and 'Population (millions)'.

# %% [markdown]
# ### Hypothesis 2.4:  Is a channel’s video views associated/dependent with the channel’s creation date?
#
#     In exploring the potential relationship between a Youtuber's total number of video views and the creation date of their channel. We investigate whether the age of a channel, indicated by its creation date, has a statistically significant association with the overall count of video views. A YouTube channel's creation date significantly influences its total number of video views, with the age of the channel serving as an indicator of its establishment within the platform. This aspect may impact visibility, reputation, and viewer engagement over time. In uncovering whether older channels tend to have higher video views or if newer channels can also achieve significant viewership, understanding this potential association provides insights into the impact of a channel's longevity on its overall video viewership.
#
# **`Null Hypothesis:`** There is no association between video views and the creation date of the YouTube channel.
#
# **`Alternative Hypothesis:`** There is a significant association between video views and the creation date of the YouTube channel.

# %%
data = {'video views': normalized_df['video views (millions)'],
        'created_year': normalized_df['created_year']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['video views'], df['created_year'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -17.02533342260726
# p-value = 1.3670723655117737e-59

# %% [markdown]
# #### Findings and Results for Hypothesis 2.4
#
#    Based on the results and findings of the T-test statistic investigating the association between a Youtuber's video views and the YouTube Channel's creation date, the t-test statistic yielded a value of . The associated p-value, calculated as , represents the probability of obtaining the observed results under the assumption of no association.
#    Based on the results and findings of the t-test investigating the association between a Youtuber's Video Views and the Year of Creation, it yielded a t-statistic value of **`-17.0253`**. This suggests that the mean difference between the groups (i.e., the differences in 'video views (millions)' and 'created_year') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`1.3671e-59`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'video views (millions)' and 'created_year'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'video views (millions)' and 'created_year' variables do significantly explain the variation in 'video views (millions)' and 'created_year'.

# %% [markdown]
# ### Hypothesis 2.5:  Is a channel’s video views associated/dependent with the channel’s average yearly earnings?
#     In investigating the potential relationship between a Youtuber's total number of video views and the channel's average yearly earnings. The objective is to determine whether the financial success of a channel, represented by its average yearly earnings, has a statistically significant association with the overall count of video views. A Youtuber's video views may be significantly linked to the average yearly earnings of their channel, with financial success serving as an indicator of popularity, content quality, and audience engagement. Examining the association between video views and average yearly earnings, implies whether channels with higher video views tend to generate greater financial returns, providing insights into the financial dynamics of a channel's success and its correlation with video viewership.
#
# **`Null Hypothesis:`** There is no association or dependence between a channel's video views and its average yearly earnings.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between a channel's video views and its average yearly earnings.

# %%
data = {'video views': normalized_df['video views (millions)'],
        'average_yearly_earnings': normalized_df['average_yearly_earnings']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['video views'], df['average_yearly_earnings'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = 13.761028692342409
# p-value = 1.1234301749599041e-40

# %% [markdown]
# #### Findings and Results for Hypothesis 2.5
#
#    Based on the results and findings of the t-test investigating the association between a Youtuber's video views and the average yearly earnings (in dollars), it yielded a t-statistic value of **`13.7610`**. This suggests that the mean difference between the groups (i.e., the differences in 'video views (millions)' and 'average_yearly_earnings') is significantly larger than the variance within the groups.
#
# The associated p-value, calculated as **`1.1234e-40`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'video views (millions)' and 'average_yearly_earnings'.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'video views (millions)' and 'average_yearly_earnings' variables do significantly explain the variation in 'video views (millions)' and 'average_yearly_earnings'

# %% [markdown]
# ### Hypothesis 2.6: Is video views associated with category?
#     In exploring whether a Youtuber's video views are statistically associated with the category of their channel. The hypothesis suggests a significant association or dependence between a channel's video views and its content category, aiming to understand how the type of content, represented by the category, correlates with overall engagement reflected in video views, seeking to uncover whether specific categories tend to attract higher video views and if viewership patterns vary across different content genres.
#
# **`Null Hypothesis:`** There is no association or dependence between a channel's video views and its category.
#
# **`Alternative Hypothesis:`** There is a significant association or dependence between a channel's video views and its category.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['video views (millions)'][youtube_df['category'] == 'Music'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Sports'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Entertainment'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Film & Animation'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Education'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Gaming'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Comedy'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'People & Blogs'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Shows'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Trailers'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Howto & Style'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Science & Technology'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Movies'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'News & Politics'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Pets & Animals'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Autos & Vehicles'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Nonprofits & Activism'],
                    youtube_df['video views (millions)'][youtube_df['category'] == 'Travel & Events'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 8.272158676669822
# p-value: 1.8802154969771768e-19

# %% [markdown]
# #### Findings and Results for Hypothesis 2.6
# Based on the results and findings of the ANOVA test investigating the association between a Youtuber's Video Views and the channel's category, it yielded a F-statistic value of **`8.2722`**. This suggests that the variance between the groups (i.e., the differences in 'video views (millions)' between different categories) is significantly larger than the variance within the groups (i.e., the differences in 'video views (millions)' within each category).
#
# The associated p-value, calculated as **`1.8802e-19`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'video views' between the different categories.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'category' variable does significantly explain the variation in 'video views (millions)'.

# %% [markdown]
# ## Hypothesis 3
#
#     The group aims to conduct a statistical analysis to investigate potential associations or dependencies between various variables within the dataset and a Youtuber's average yearly earnings. The objective is to assess whether specific factors exhibit a statistically significant relationship with the average earnings of a Youtuber. The average earnings is calculated using both the lowest monthly income as well as the highest monthly income of each observation.

# %% [markdown]
# ### Hypothesis 3.1: Is earning associated with category?
#     In exploring the potential association between a Youtuber's average yearly earnings and the category of their channel, aiming to determine if there is a statistically significant association between a channel's average yearly earnings and its category. The focus is on assessing whether the type of content, represented by the category, influences a channel's financial success. By scrutinizing this association, the analysis aims to determine whether average yearly earnings vary across different content genres or if the category plays a negligible role in a channel's financial performance.
#
# **`Null Hypothesis:`** There is no association between a channel's average yearly earning and their category.
#
# **`Alternative Hypothesis:`** There is a significant association between a channel's average yearly earning and their category.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Music'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Sports'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Entertainment'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Film & Animation'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Education'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Gaming'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Comedy'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'People & Blogs'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Shows'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Trailers'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Howto & Style'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Science & Technology'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Movies'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'News & Politics'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Pets & Animals'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Autos & Vehicles'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Nonprofits & Activism'],
                    youtube_df['average_yearly_earnings'][youtube_df['category'] == 'Travel & Events'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 2.683353385765658
# p-value: 0.00026909174461531857

# %% [markdown]
# #### Findings and Results for Hypothesis 3.1
# Based on the results and findings of the ANOVA test investigating the association between a Youtuber's average yearly earnings and the channel's category, it yielded a F-statistic value of **`2.68335`**. This suggests that the variance between the groups (i.e., the differences in 'average_yearly_earnings' between different categories) is significantly larger than the variance within the groups (i.e., the differences in 'average_yearly_earnings' within each category).
#
# The associated p-value, calculated as **`0.0002691`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'average_yearly_earnings' between the different categories.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'Category' variable does significantly explain the variation in 'average_yearly_earnings'

# %% [markdown]
# ### Hypothesis 3.2: Is earning associated with the country of origin’s population?
#     In investigating the potential association between a Youtuber's average yearly earnings and the population of the country of origin, the group's aim is to determine wether there is an association between a channel's average yearly earnings and the population of the country of origin. The focus is on assessing whether the demographic size of the country influences a channel's financial success. By scrutinizing this association, the analysis aims to determine whether average yearly earnings vary based on the population of the country of origin or if the population size plays a negligible role in a channel's financial performance.
#
# **`Null Hypothesis:`** There is no association between a channel's average yearly earning and the population of the country of origin.
#
# **`Alternative Hypothesis:`** There is a significant association between a channel's average yearly earning and the population of the country of origin.

# %%
data = {'average_yearly_earnings': normalized_df['average_yearly_earnings'],
        'population': normalized_df['Population (millions)']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['average_yearly_earnings'], df['population'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -12.687527013828616
# p-value = 4.0329730494787495e-35

# %% [markdown]
# #### Findings and Results for Hypothesis 3.2
#    Based on the results and findings of the T-test statistic investigating the association between a Youtuber's earnings and the population of the YouTube Channel's country of origin, the t-test statistic yielded a value of **`-12.6875`**. The associated p-value, calculated as **`4.0330E-35`**, represents the probability of obtaining the observed results under the assumption of no association. The test statistic suggests a significant and negative association, signifying that there is a substantial difference in earnings based on the population of the YouTube Channel's country of origin.
#
#    In summary, these findings indicate that there is a statistically significant negative association between a Youtuber's earnings and the population of the YouTube Channel's country of origin. Therefore, **`we reject the null hypothesis`**. This suggests that the population of the country of origin plays a significant association in explaining the variation in a Youtuber's earnings based on the observed data.

# %% [markdown]
# ### Hypothesis 3.3: Is earning associated with the YouTube Channel's country of origin?
#
# In this analysis, the team explores the potential association between a Youtuber's average yearly earnings and the country of origin of their channel. The hypothesis posits that there is no association between a channel's average yearly earnings and the channel's country of origin. The focus is on assessing whether the geographic location of the channel influences a Youtuber's financial success. By scrutinizing this association, the analysis aims to determine whether average yearly earnings vary based on the channel's country of origin or if the country of origin plays a negligible role in a channel's financial performance.
#
# **`Null Hypothesis:`** There is no association between a channel's average yearly earning and the channel's country of origin.
#
# **`Alternative Hypothesis:`** There is a significant association between a channel's average yearly earning and the channel's country of origin.

# %%
# Perform the ANOVA
f, p = stats.f_oneway(youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Canada'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'South Korea'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'United States'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'India'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'United Kingdom'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Chile'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Russia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Cuba'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'El Salvador'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Mexico'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Barbados'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Colombia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Thailand'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Brazil'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Spain'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Argentina'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Saudi Arabia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'United Arab Emirates'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Indonesia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Philippines'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Venezuela'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Kuwait'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Jordan'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Netherlands'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Pakistan'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Australia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Japan'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Germany'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'France'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Sweden'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Ukraine'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Turkey'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Switzerland'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Vietnam'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Malaysia'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'China'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Iraq'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Singapore'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Egypt'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Ecuador'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Morocco'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Peru'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Finland'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Samoa'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Italy'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Germany'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'France'],
                    youtube_df['average_yearly_earnings'][youtube_df['Country'] == 'Sweden'],)

print('F-statistic:', f)
print('p-value:', p)
# Out:
# F-statistic: 1.7460194140499556
# p-value: 0.001852745857323831

# %% [markdown]
# #### Findings and Results of Hypothesis 3.3
# Based on the results and findings of the ANOVA test investigating the association between a Youtuber's average yearly earnings and the country of origin, it yielded an F-statistic value of **`1.7460`**. This suggests that the variance between the groups (i.e., the differences in 'average_yearly_earnings' between different countries) is significantly larger than the variance within the groups (i.e., the differences in 'average_yearly_earnings' within each country).
#
# The associated p-value, calculated as **`0.001852745857323831`**, represents the probability of obtaining the observed results under the assumption of no association. In terms of the decision criterion, when comparing the p-value to the significance level (α) of **`0.05`**, it is less than the significance level.
#
# In summary, these findings indicate that **`there is enough evidence to conclude that there is a significant difference in 'average_yearly_earnings' between the different countries.`** Therefore we **`reject`** the null hypothesis. This suggests that the 'Country' variable does significantly explain the variation in 'average_yearly_earnings'.

# %% [markdown]
# ### Hypothesis 3.4: Is earning associated with the YouTube Channel's upload count?
#     Delving into the exploration of whether a Youtuber's average yearly earnings are significantly associated with the upload count of their channel. We aim to determine whether that there is no statistically significant association between a channel's average yearly earnings and the channel's upload count. The emphasis lies in discerning whether the frequency of content uploads, represented by the upload count, playing a crucial role in a Youtuber's financial success. By scrutinizing this association, we get to unveil valuable insights into whether average yearly earnings are influenced by the consistent production of content, contributing to a deeper understanding of the factors that impact a channel's financial performance.
#
# **`Null Hypothesis:`** There is no association between a channel's average yearly earning and the channel's upload count.
#
# **`Alternative Hypothesis:`** There is a significant association between a channel's average yearly earning and the channel's upload count.

# %%
data = {'average_yearly_earnings': normalized_df['average_yearly_earnings'],
        'uploads': normalized_df['uploads']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['average_yearly_earnings'], df['uploads'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = 12.244974305425535
# p-value = 6.187229366244899e-33

# %% [markdown]
# #### Findings and Results for Hypothesis 3.4
#
# In investigating the potential association between a Youtuber's average yearly earnings and the upload count of their channel, the T-test yielded a highly significant result. The t-statistic of **`12.2450`** and the extremely low p-value of **`6.1872e-33`** provide robust evidence of a positive association. This suggests that as the upload count increases, a Youtuber's average yearly earnings tend to increase as well. Therefore, **`we reject the null hypothesis`**, concluding that there is a significant positive association between a Youtuber's average yearly earnings and the upload count of their channel. This underscores the pivotal role of consistent content production in contributing to a Youtuber's financial success.

# %% [markdown]
# ### Hypothesis 3.5: Is earning associated with the YouTube Channel's creation date?
#     In this exploration, the team investigates whether a Youtuber's average yearly earnings are significantly associated with the creation date of their channel, determining if there is an association between a channel's average yearly earnings and the channel's creation date. The focus is on assessing whether the age of a channel, as indicated by its creation date, plays a crucial role in a Youtuber's financial success, aiding in determining whether average yearly earnings vary based on the channel's longevity or if the creation date holds a negligible impact on a channel's financial performance.
#
# **`Null Hypothesis:`** There is no association between a channel's average yearly earning and the channel's creation date.
#
# **`Alternative Hypothesis:`** There is a significant association between a channel's average yearly earning and the channel's creation date.

# %%
data = {'average_yearly_earnings': normalized_df['average_yearly_earnings'],
        'created_year': normalized_df['created_year']}
df = pd.DataFrame(data)

t_stat, p_value = stats.ttest_ind(df['average_yearly_earnings'], df['created_year'])

print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -30.042394774772504
# p-value = 8.417122125979196e-156

# %% [markdown]
# #### Findings and Results for Hypothesis 3.5
# The T-test results indicate a highly significant and negative association **`(t-statistic = -30.0424, p-value = 8.4171e-156)`** between a Youtuber's average yearly earnings and the creation date of their channel. This suggests that, on average, older channels tend to have higher average yearly earnings. Therefore, **`we reject the null hypothesis`**, highlighting the influential role of channel longevity in a Youtuber's financial success; there is a significant association between a channel's average yearly earning and the channel's creation date.

# %% [markdown]
# ## Insights and Conclusion

# %% [markdown]
#     In analyzing the dataset, several key insights emerge regarding the factors associated with channel performance on the platform. Subscribers exhibit a correlation with category, population size, creation date, video views, and upload count suggesting that channels with larger populations and longer histories tend to attract more subscribers. It also suggests that the category of the channel as well as thei video views and upload count influence the number of subscribers. Notably, no significant associations were found between subscriber count and variables such as country and earnings. Video views, on the other hand, display correlations with all the variables. Similarly, earnings are linked to population size, the number of uploads, creation date, country, and category. However, both video views and earnings show significant associations with variables like country, upload count, category, or demographic factors. Furthermore, these associations suggest that the population size of the country of origin, creation date, category, and upload count consistently show a correlation with all three main variables (subscribers, video views, and earnings). Additionally, population size, the number of uploads, creation date, country, and category are all associated with earnigns. These insights provide a basis for understanding which factors are most likely to influence the success of a channel on the platform.
#
#     Further analysis is warranted to explore the relationships between these other untested variables such as demographic variables e.g. unemployment rate, and the platform metrics, providing a more comprehensive understanding of the factors influencing channel success.

# %% [markdown]
#     - End of Document -
